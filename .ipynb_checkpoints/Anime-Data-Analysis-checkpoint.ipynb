# %% [markdown]
# ## [Chosen Dataset: myanimelist-dataset-animes-profiles-reviews](https://www.kaggle.com/marlesson/myanimelist-dataset-animes-profiles-reviews)
# - project data_animes.csv
# - project_data_profiles.csv
# - project_data_reviews.csv

# %%
# !pip install fuzzywuzzy import process
# !pip install plotly
# !pip install wordcloud
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\13475\anaconda3\lib\site-packages (0.18.0)
# ERROR: Could not find a version that satisfies the requirement import (from versions: none)
# ERROR: No matching distribution found for import

# %%
# Libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import json
from scipy.sparse import csr_matrix
import pickle

# %matplotlib inline

# %%
df_profile = pd.read_csv('data/project_data_profiles.csv', sep=',')
df_profile.head()
# Out:
#            profile  gender      birthday  \
# 0   DesolatePsyche    Male   Oct 2, 1994
# 1        baekbeans  Female  Nov 10, 2000
# 2             skrn     NaN           NaN
# 3     edgewalker00    Male         Sep 5
# 4  aManOfCulture99    Male  Oct 30, 1999
#
#                                      favorites_anime  \
# 0  ['33352', '25013', '5530', '33674', '1482', '2...
# 1  ['11061', '31964', '853', '20583', '918', '925...
# 2  ['918', '2904', '11741', '17074', '23273', '32...
# 3           ['5680', '849', '2904', '3588', '37349']
# 4  ['4181', '7791', '9617', '5680', '2167', '4382...
#
#                                               link
# 0   https://myanimelist.net/profile/DesolatePsyche
# 1        https://myanimelist.net/profile/baekbeans
# 2             https://myanimelist.net/profile/skrn
# 3     https://myanimelist.net/profile/edgewalker00
# 4  https://myanimelist.net/profile/aManOfCulture99

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df_anime = pd.read_csv('data/project_data_animes.csv', sep=',')
# rename column "uid" to "anime_uid"
df_anime = df_anime.rename(columns={'uid': 'anime_uid'})
# pickle.dump(df_anime, open('models/df_anime.pkl', 'wb') )

# %%
df_review= pd.read_csv('data/project_data_reviews.csv', sep=',')
df_review.head()
# Out:
#       uid          profile  anime_uid  \
# 0  255938   DesolatePsyche      34096
# 1  259117        baekbeans      34599
# 2  253664             skrn      28891
# 3    8254     edgewalker00       2904
# 4  291149  aManOfCulture99       4181
#
#                                                 text  score  \
# 0  \n           \n         \n           \n       ...      8
# 1  \n           \n         \n           \n       ...     10
# 2  \n           \n         \n           \n       ...      7
# 3  \n           \n         \n           \n       ...      9
# 4  \n           \n         \n           \n       ...     10
#
#                                               scores  \
# 0  {'Overall': '8', 'Story': '8', 'Animation': '8...
# 1  {'Overall': '10', 'Story': '10', 'Animation': ...
# 2  {'Overall': '7', 'Story': '7', 'Animation': '9...
# 3  {'Overall': '9', 'Story': '9', 'Animation': '9...
# 4  {'Overall': '10', 'Story': '10', 'Animation': ...
#
#                                             link
# 0  https://myanimelist.net/reviews.php?id=255938
# 1  https://myanimelist.net/reviews.php?id=259117
# 2  https://myanimelist.net/reviews.php?id=253664
# 3    https://myanimelist.net/reviews.php?id=8254
# 4  https://myanimelist.net/reviews.php?id=291149

# %% [markdown]
# ---
#
# ## Join/merge datasets
#
# ---

# %%
anime_review_data=pd.merge(df_anime,df_review,on='anime_uid',suffixes= ['', '_review'])
anime_full_data = pd.merge(anime_review_data, df_profile, on='profile', suffixes=['','_profile'])
import pickle
pickle.dump(anime_full_data, open('models/anime_full_data.pkl', 'wb') )
anime_review_data.head()
# Out:
#    anime_uid                    title  \
# 0      28891  Haikyuu!! Second Season
# 1      28891  Haikyuu!! Second Season
# 2      28891  Haikyuu!! Second Season
# 3      28891  Haikyuu!! Second Season
# 4      28891  Haikyuu!! Second Season
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Following their participation at the Inter-Hig...
# 2  Following their participation at the Inter-Hig...
# 3  Following their participation at the Inter-Hig...
# 4  Following their participation at the Inter-Hig...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 2  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 3  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 4  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
#
#                          aired  episodes  members  popularity  ranked  score  \
# 0  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 2  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 3  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 4  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/9/766...
# 2  https://cdn.myanimelist.net/images/anime/9/766...
# 3  https://cdn.myanimelist.net/images/anime/9/766...
# 4  https://cdn.myanimelist.net/images/anime/9/766...
#
#                                                 link     uid      profile  \
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...  253664         skrn
# 1  https://myanimelist.net/anime/28891/Haikyuu_Se...  254554    Tactician
# 2  https://myanimelist.net/anime/28891/Haikyuu_Se...  271227  CallMeDette
# 3  https://myanimelist.net/anime/28891/Haikyuu_Se...  284956  jason200911
# 4  https://myanimelist.net/anime/28891/Haikyuu_Se...  249279    comiclove
#
#                                                 text  score_review  \
# 0  \n           \n         \n           \n       ...             7
# 1  \n           \n         \n           \n       ...            10
# 2  \n           \n         \n           \n       ...            10
# 3  \n           \n         \n           \n       ...             7
# 4  \n           \n         \n           \n       ...             8
#
#                                               scores  \
# 0  {'Overall': '7', 'Story': '7', 'Animation': '9...
# 1  {'Overall': '10', 'Story': '10', 'Animation': ...
# 2  {'Overall': '10', 'Story': '10', 'Animation': ...
# 3  {'Overall': '7', 'Story': '7', 'Animation': '7...
# 4  {'Overall': '8', 'Story': '7', 'Animation': '7...
#
#                                      link_review
# 0  https://myanimelist.net/reviews.php?id=253664
# 1  https://myanimelist.net/reviews.php?id=254554
# 2  https://myanimelist.net/reviews.php?id=271227
# 3  https://myanimelist.net/reviews.php?id=284956
# 4  https://myanimelist.net/reviews.php?id=249279

# %%
selections = ['anime_uid','title','synopsis','score','img_url']
anime_data = anime_review_data[selections]
pickle.dump(anime_data, open('models/anime_data.pkl', 'wb') )

# %% [markdown]
# ---
# ## Creating a dataframe that shows top 10 anime based on score counts
# ---

# %%
def TopTenBasedOnScore():
 
    combine_anime_rating = anime_full_data.dropna(axis = 0, subset = ['title'])
    anime_ratingCount = (combine_anime_rating.
                        groupby(by=['anime_uid','title'])['score_review'].count().
                        reset_index().rename(columns = {'score':'totalScoreCount'})
                        [['anime_uid','title','score_review']])
    pickle.dump(anime_ratingCount, open('models/anime_ratingCount.pkl', 'wb') )
    #Plotting the bar plot for top 10 anime as per rating 
    top10_animerating=anime_ratingCount[['anime_uid','title', 'score_review']].sort_values(by = 'score_review',ascending = False).head(10)
    ax=sns.barplot(x="title", y="score_review", data=top10_animerating, palette="Dark2")
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=11, rotation=40, ha="right")
    ax.set_title('Top 10 Anime based on score/rating counts',fontsize = 22)
    ax.set_xlabel('Anime',fontsize = 20) 
    ax.set_ylabel('User Rating count', fontsize = 20)
    
   
TopTenBasedOnScore()

# %%
combine_anime_rating = anime_full_data.dropna(axis = 0, subset = ['title'])
anime_ratingCount = (combine_anime_rating.
                    groupby(by=['anime_uid','title','img_url','synopsis'])['score_review'].count().
                    reset_index().rename(columns = {'score':'totalScoreCount'})
                    [['anime_uid','title','score_review','img_url','synopsis']])
pickle.dump(anime_ratingCount, open('models/anime_ratingCount.pkl', 'wb') )

top10_animerating=anime_ratingCount[['anime_uid','title', 'score_review','img_url','synopsis']].sort_values(by = 'score_review',ascending = False).head(5)


# for idd in top10_animerating['anime_uid']:

#     print(df_anime[df_anime['anime_uid']==idd]['title'].values[0])
#     print(anime_full_data[anime_full_data['anime_uid']==idd]['synopsis'].values[0])
#     print(df_anime[df_anime['anime_uid']==idd]['score'].values[0])

# %% [markdown]
# ---
# ## Creating a dataframe that shows top 10 anime based on Community size
# ---

# %%
def TopTenBasedOnCommunitySize():
    duplicate_anime=anime_full_data.copy()
    duplicate_anime.drop_duplicates(subset ="title", 
                         keep = 'first', inplace = True)
    #Plotting bar plot               
    top10_animemembers=duplicate_anime[['title', 'members']].sort_values(by = 'members',ascending = False).head(10)
    ax=sns.barplot(x="title", y="members", data=top10_animemembers, palette="gnuplot2")
    ax.set_xticklabels(ax.get_xticklabels(), fontsize=11, rotation=40, ha="right")
    ax.set_title('Top 10 Anime based on members',fontsize = 22)
    ax.set_xlabel('Anime',fontsize = 20) 
    ax.set_ylabel('Community Size', fontsize = 20)
TopTenBasedOnCommunitySize()

# %%
def RatingGraph(): 
    #Distribution of ratings
    plt.figure(figsize = (15, 7))
    plt.subplot(1,2,1)
    anime_full_data['score'].hist(bins=70)
    plt.title("Rating of websites")
    plt.subplot(1,2,2)
    anime_full_data['score_review'].hist(bins=70)
    plt.title("Rating of users")
RatingGraph()

# %%
# anime_full_data.isnull().sum()

# %% [markdown]
# ## Genre Word Cloud

# %%
nonull_anime=anime_full_data.copy()
nonull_anime.dropna(inplace=True)
from collections import defaultdict

all_genres = defaultdict(int)

for genres in nonull_anime['genre']:
    for genre in genres.split(','):
        all_genres[genre.strip()] += 1
        
from wordcloud import WordCloud

genres_cloud = WordCloud(width=800, height=400, background_color='white', colormap='gnuplot').generate_from_frequencies(all_genres)
plt.imshow(genres_cloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %%
#Replacing -1 with NaN in user_rating column
anime_feature=anime_full_data.copy()
anime_feature["score_review"].replace({-1: np.nan}, inplace=True)
anime_feature.head()
# Out:
#    anime_uid                    title  \
# 0      28891  Haikyuu!! Second Season
# 1      28891  Haikyuu!! Second Season
# 2      28891  Haikyuu!! Second Season
# 3      28891  Haikyuu!! Second Season
# 4      28891  Haikyuu!! Second Season
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Following their participation at the Inter-Hig...
# 2  Following their participation at the Inter-Hig...
# 3  Following their participation at the Inter-Hig...
# 4  Following their participation at the Inter-Hig...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 2  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 3  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 4  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
#
#                          aired  episodes  members  popularity  ranked  score  \
# 0  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 2  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 3  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 4  Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/9/766...
# 2  https://cdn.myanimelist.net/images/anime/9/766...
# 3  https://cdn.myanimelist.net/images/anime/9/766...
# 4  https://cdn.myanimelist.net/images/anime/9/766...
#
#                                                 link     uid profile  \
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...  253664    skrn
# 1  https://myanimelist.net/anime/28891/Haikyuu_Se...  253664    skrn
# 2  https://myanimelist.net/anime/28891/Haikyuu_Se...  253664    skrn
# 3  https://myanimelist.net/anime/28891/Haikyuu_Se...  253664    skrn
# 4  https://myanimelist.net/anime/28891/Haikyuu_Se...  253664    skrn
#
#                                                 text  score_review  \
# 0  \n           \n         \n           \n       ...             7
# 1  \n           \n         \n           \n       ...             7
# 2  \n           \n         \n           \n       ...             7
# 3  \n           \n         \n           \n       ...             7
# 4  \n           \n         \n           \n       ...             7
#
#                                               scores  \
# 0  {'Overall': '7', 'Story': '7', 'Animation': '9...
# 1  {'Overall': '7', 'Story': '7', 'Animation': '9...
# 2  {'Overall': '7', 'Story': '7', 'Animation': '9...
# 3  {'Overall': '7', 'Story': '7', 'Animation': '9...
# 4  {'Overall': '7', 'Story': '7', 'Animation': '9...
#
#                                      link_review gender birthday  \
# 0  https://myanimelist.net/reviews.php?id=253664    NaN      NaN
# 1  https://myanimelist.net/reviews.php?id=253664    NaN      NaN
# 2  https://myanimelist.net/reviews.php?id=253664    NaN      NaN
# 3  https://myanimelist.net/reviews.php?id=253664    NaN      NaN
# 4  https://myanimelist.net/reviews.php?id=253664    NaN      NaN
#
#                                      favorites_anime  \
# 0  ['918', '2904', '11741', '17074', '23273', '32...
# 1  ['918', '2904', '11741', '17074', '23273', '32...
# 2  ['918', '2904', '11741', '17074', '23273', '32...
# 3  ['918', '2904', '11741', '17074', '23273', '32...
# 4  ['918', '2904', '11741', '17074', '23273', '32...
#
#                            link_profile
# 0  https://myanimelist.net/profile/skrn
# 1  https://myanimelist.net/profile/skrn
# 2  https://myanimelist.net/profile/skrn
# 3  https://myanimelist.net/profile/skrn
# 4  https://myanimelist.net/profile/skrn

# %%
#dropping all the null values as it aids nothing
anime_feature = anime_feature.dropna(axis = 0, how ='any') 
anime_feature.isnull().sum()
# Out:
# anime_uid          0
# title              0
# synopsis           0
# genre              0
# aired              0
# episodes           0
# members            0
# popularity         0
# ranked             0
# score              0
# img_url            0
# link               0
# uid                0
# profile            0
# text               0
# score_review       0
# scores             0
# link_review        0
# gender             0
# birthday           0
# favorites_anime    0
# link_profile       0
# dtype: int64

# %%
counts = anime_feature['uid'].value_counts()

# %% [markdown]
# ### There are users who has rated only once, even if they have rated it 5, it can’t be considered a valuable record for recommendation, so let's considered minimum 10 ratings by the user as threshold value.

# %%
anime_feature = anime_feature[anime_feature['uid'].isin(counts[counts >= 10].index)]
# anime_feature['uid'].value_counts()

# %% [markdown]
# # pivot table
# pivot table helps create sparse matrix, which can help for cosine similarity.

# %%
# anime_full_data = anime_full_data.drop_duplicates(['uid','title'])
# anime_pivot = anime_full_data.pivot_table(index = 'title', columns = 'uid', values='score_review').fillna(0)

# %% [markdown]
# ---
#
# ## Another approach to get the anime_pivot if ``pivot_table`` uses too much memory

# %%
# testing = anime_full_data.groupby(['title','uid'])['score_review'].max().unstack().fillna(0)
# testing.head()

# %%
# print(anime_pivot.shape)
# print(testing.shape)
print(anime_full_data.shape)
anime_full_data = anime_full_data.drop_duplicates(['uid','title'])
print(anime_full_data.shape)
# Out:
# (811636, 22)
# (130519, 22)

# %% [markdown]
# ---

# %% [markdown]
# ## Recommendation based on Collaborative Filtering

# %%
anime_full_data = anime_full_data.drop_duplicates(['title'])
anime_pivot = anime_full_data.pivot_table(index = 'title', columns = 'uid', values='score_review').fillna(0)
# creating a sparse martix
anime_matrix = csr_matrix(anime_pivot.values)
# fitting the model. Cosine Similarity using KNN.
from sklearn.neighbors import NearestNeighbors
knnmodel = NearestNeighbors(metric = 'cosine', algorithm = 'brute', n_neighbors=20)
knnmodel.fit(anime_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=20)

# %%
# anime_pivot.head()

# %% [markdown]
# ## Testing collaborative filtering recommendation function

# %%
knnmodel
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_neighbors=20)

# %%
arr = []
for i in range(len(anime_pivot)):
    arr.append(df_anime['title'][int(i)])
def recommend_collaborative_filtering(anime_name, model, n_recommendations):
    idx = arr.index(anime_name)
   # idx = process.extractOne(anime_name, df_anime['title'] )[2]   # using fuzzywuzzy to find the corresponding anime title
    print('Anime Selected: ',df_anime['title'][idx],'Index: ',idx )
    print('Searching for recommendations......')
    distances, indices = model.kneighbors(anime_matrix[idx], n_neighbors = n_recommendations)
    for i in indices:
        print(df_anime['title'][i])
recommend_collaborative_filtering('Death Note',  knnmodel, 6)
print()
recommend_collaborative_filtering('Steins;Gate', knnmodel, 6)
# Out:
# Anime Selected:  Death Note Index:  740
# Searching for recommendations......
# 740                                            Death Note
# 5408                        Isekai no Seikishi Monogatari
# 5409                   Shokugeki no Souma: Ni no Sara OVA
# 5411                                  Xiao Lu He Xiao Lan
# 5407    Soukyuu no Fafner: Dead Aggressor - Exodus 2nd...
# 5412                            Kuroko no Basket: Tip Off
# Name: title, dtype: object
#
# Anime Selected:  Steins;Gate Index:  773
# Searching for recommendations......
# 773                                           Steins;Gate
# 5407    Soukyuu no Fafner: Dead Aggressor - Exodus 2nd...
# 5408                        Isekai no Seikishi Monogatari
# 5410                                 Coquelicot-zaka kara
# 5406    Kaleido Star: Legend of Phoenix - Layla Hamilt...
# 5411                                  Xiao Lu He Xiao Lan
# Name: title, dtype: object

# %%
def testing(anime_name, model, n_recommendations):
    res = []
    idx = arr.index(anime_name)
   # idx = process.extractOne(anime_name, df_anime['title'] )[2]   # using fuzzywuzzy to find the corresponding anime title
#     print('Anime Selected: ',df_anime['title'][idx],'Index: ',idx )
#     print('Searching for recommendations......')
    distances, indices = model.kneighbors(anime_matrix[idx], n_neighbors = n_recommendations)
    for i in indices:
        res.append(df_anime['title'][i].values)
    return res

# %%
collaborative_filtering_rec = {}

for anime_title in df_anime.title.unique():
  
   
    try:
        title_list =testing(anime_title,knnmodel, 11 )
        collaborative_filtering_rec[anime_title]=title_list
    except: 
        pass
# collaborative_filtering_rec

# %%
pickle.dump(collaborative_filtering_rec, open('models/collaborative_filtering_rec.pkl', 'wb') )

# %%
collaborative_filtering_rec['Xiao Lu He Xiao Lan']
# Out:
# [array(['Xiao Lu He Xiao Lan', 'Xiao Lu He Xiao Lan',
#         'Hidamari Sketch x ☆☆☆',
#         'Soukyuu no Fafner: Dead Aggressor - Exodus 2nd Season',
#         'Isekai no Seikishi Monogatari',
#         'Shokugeki no Souma: Ni no Sara OVA', 'Coquelicot-zaka kara',
#         'Kara no Kyoukai 4: Garan no Dou', 'Brotherhood: Final Fantasy XV',
#         'Smile Precure!', 'Kuroko no Basket: Tip Off'], dtype=object)]

# %%
results =[]
user_input_text='Death Note'
collaborative_img_url=[]
for index in range(len(collaborative_filtering_rec[user_input_text][0])):
    if index <6:
        anime_title = collaborative_filtering_rec[user_input_text][0][index]
        results.append(anime_title)
        img_url = (df_anime[df_anime['title']==anime_title]['img_url'].values[0])
        collaborative_img_url.append(img_url)
print((collaborative_img_url))
print((results))
# Out:
# ['https://cdn.myanimelist.net/images/anime/9/9453.jpg', 'https://cdn.myanimelist.net/images/anime/1670/93590.jpg', 'https://cdn.myanimelist.net/images/anime/10/76803.jpg', 'https://cdn.myanimelist.net/images/anime/7/76538.jpg', 'https://cdn.myanimelist.net/images/anime/2/20345.jpg', 'https://cdn.myanimelist.net/images/anime/1032/96640.jpg']
# ['Death Note', 'Xiao Lu He Xiao Lan', 'Kuroko no Basket: Tip Off', 'Soukyuu no Fafner: Dead Aggressor - Exodus 2nd Season', 'Isekai no Seikishi Monogatari', 'Shokugeki no Souma: Ni no Sara OVA']

# %% [markdown]
# ## Old Approach collaborative filtering recommendation

# %%
# # get a random anime title and find recommendation for it.
# query = np.random.choice(anime_pivot.shape[0])

# def print_rec(query):
#     distances, indices = knnmodel.kneighbors(anime_pivot.iloc[query,:].values.reshape(1, -1), n_neighbors=5)
#     # ^ returning the distances and indices of 6 neighbours through KNN from the randomly chosen index(anime_title) 

#     # print(distances, indices)
#     for i in range(0, len(distances.flatten())):
#         if i==0:
#             print('Recommendations for {0}:'.format(anime_pivot.index[query]))
#         else:
#             print('\t{0}: {1}, with distance of {2}:'.format(i, anime_pivot.index[indices.flatten()[i]], distances.flatten()[i]))
            
# print_rec(query)

# %% [markdown]
# ## Makes an array of anime as it's string name, not the anime id

# %%
# arr = []

# for i in range(len(anime_pivot)):
#     arr.append(anime_pivot.index[int(i)])
# #     print(anime_pivot.index[int(i)])

# %% [markdown]
# ## User is allowed to enter input (the index) instead of it being randomly chosen.

# %%
# inp = input ("enter a num ")
# # anime_pivot.index[int(inp)]
# query = int(inp)
# print_rec(query)

# %%
## User gets recommendations based on the anime title.

# %%
# query = arr.index("A.I.C.O.: Incarnation")
# print_rec(query)

# %% [markdown]
# ## Recommendation based on Content-Based Filtering (only using ``project data_animes.csv`` data )

# %%
# cleaning anime_title

import re
def text_cleaning(text):
    text = re.sub(r'&quot;', '', text)
    text = re.sub(r'.hack//', '', text)
    text = re.sub(r'&#039;', '', text)
    text = re.sub(r'A&#039;s', '', text)
    text = re.sub(r'I&#039;', 'I\'', text)
    text = re.sub(r'&amp;', 'and', text)
    return text

df_anime['title'] = df_anime['title'].apply(text_cleaning)
print(df_anime.shape)
df_anime = df_anime.drop_duplicates('title')
print(df_anime.shape)
# Out:
# (19311, 12)
# (16213, 12)

# %%
# Term Frequency (TF) and Inverse Document Frequency (IDF)
from sklearn.feature_extraction.text import TfidfVectorizer
#getting tfidf
tfv = TfidfVectorizer(min_df=3,  max_features=None, 
            strip_accents='unicode', analyzer='word',token_pattern=r'\w{1,}',
            ngram_range=(1, 3),
            stop_words = 'english')

# Filling NaNs with empty string
df_anime['genre'] = df_anime['genre'].fillna('')
genres_str = df_anime['genre'].str.split(',').astype(str)
tfv_matrix = tfv.fit_transform(genres_str)
# Out:
# (16213, 12)

# %%
df_anime.head()
# Out:
#    anime_uid                             title  \
# 0      28891           Haikyuu!! Second Season
# 1      23273           Shigatsu wa Kimi no Uso
# 2      34599                     Made in Abyss
# 3       5114  Fullmetal Alchemist: Brotherhood
# 4      31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/3/671...
# 2  https://cdn.myanimelist.net/images/anime/6/867...
# 3  https://cdn.myanimelist.net/images/anime/1223/...
# 4  https://cdn.myanimelist.net/images/anime/3/815...
#
#                                                 link
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...
# 4  https://myanimelist.net/anime/31758/Kizumonoga...

# %%
from sklearn.metrics.pairwise import sigmoid_kernel
# Compute the sigmoid kernel
sig = sigmoid_kernel(tfv_matrix, tfv_matrix)
#getting the indices of anime title
indices = pd.Series(df_anime.index, index=df_anime['title']).drop_duplicates()

# %%
indices['Death Note']
# Out:
# 740

# %% [markdown]
# ## Random anime chosen + recommendation function

# %%
# # get a random anime title and find recommendation for it.
# query = np.random.choice(anime_pivot.shape[0])

# def print_rec(query):
#     distances, indices = knnmodel.kneighbors(anime_pivot.iloc[query,:].values.reshape(1, -1), n_neighbors=5)
#     # ^ returning the distances and indices of 6 neighbours through KNN from the randomly chosen index(anime_title) 

#     # print(distances, indices)
#     for i in range(0, len(distances.flatten())):
#         if i==0:
#             print('Recommendations for {0}:'.format(anime_pivot.index[query]))
#         else:
#             print('\t{0}: {1}, with distance of {2}:'.format(i, anime_pivot.index[indices.flatten()[i]], distances.flatten()[i]))
            
# print_rec(query)

# %% [markdown]
# ## makes an array of anime as it's string name, not the anime id

# %%
arr = []

for i in range(len(anime_pivot)):
    arr.append(anime_pivot.index[int(i)])
#     print(anime_pivot.index[int(i)])

# %% [markdown]
# ## User is allowed to enter input (the index) instead of it being randomly chosen.

# %%
def recommend(title, sig=sig):
    # Get the index corresponding to original_title
    idx = indices[title]   
    res = []
    #Get the pairwsie similarity scores 
    sig_scores = list(enumerate(sig[idx]))
    # Sort the movies 
    sig_scores = sorted(sig_scores, key=lambda x: x[1], reverse=True)
    # Scores of the 10 most similar movies
    sig_scores = sig_scores[1:11]
    # Anime indices
    anime_indices = [i[0] for i in sig_scores]
    for anime_title in df_anime['title'].iloc[anime_indices].values:
        res.append(anime_title)
    return res;
A
    # Top 10 most similar movies
#     return pd.DataFrame({'Anime title': df_anime['title'].iloc[anime_indices].values,
#                                  'Rating': df_anime['score'].iloc[anime_indices].values})

# Testing it with different anime titles
print(recommend('Death Note'))
print()
print(recommend('Dragon Ball Z'))
print()
print(recommend('Steins;Gate'))
print()
# Out:
# ['Death Note: Rewrite', 'B: The Beginning', 'B: The Beginning 2', 'Imawa no Kuni no Alice (OVA)', 'Mo Ri Shu Guang', 'Higurashi no Naku Koro ni Kai', 'Bloody Night', 'Mouryou no Hako', 'Mousou Dairinin', 'Top Secret: The Revelation']
#
# ['Dragon Ball Kai', 'Dragon Ball Kai (2014)', 'Dragon Ball Z Movie 11: Super Senshi Gekiha!! Katsu no wa Ore da', 'Dragon Ball Z Movie 15: Fukkatsu no "F"', 'Dragon Ball', 'Dragon Ball Heroes', 'Shaolin Chuanqi', 'Dragon Ball Z Movie 14: Kami to Kami', 'Dragon Ball Z Movie 10: Kiken na Futari! Super Senshi wa Nemurenai', 'Kyutai Panic Adventure!']
#
# ['Uchiko no Mama to Okaasan', 'Steins;Gate: Oukoubakko no Poriomania', 'Hello World', 'Mou Hitotsu no Mirai wo.', 'Hoshi no Ko Poron', 'Amanatsu', 'Adachi-ga Hara', 'Seikaisuru Kado: Ekwari', 'Mirai Arise', '100-man-nen Chikyuu no Tabi: Bander Book']

# %%
content_based_rec = {}

for anime_title in df_anime.title.unique():
    try:
        title_list =recommend(anime_title )
        content_based_rec[anime_title]=title_list
    except: 
        pass
content_based_rec
# Out:
# {'Haikyuu!! Second Season': ['Haikyuu!!: Karasuno Koukou vs. Shiratorizawa Gakuen Koukou',
#   'Haikyuu!! Movie 2: Shousha to Haisha',
#   'Haikyuu!! Movie 1: Owari to Hajimari',
#   'Slam Dunk',
#   'Haikyuu!!',
#   'Haikyuu!!: To the Top',
#   'Haikyuu!!: Riku vs. Kuu',
#   'Ahiru no Sora',
#   'Slam Dunk: Zenkoku Seiha Da! - Sakuragi Hanamichi',
#   'Battle Athletess Daiundoukai (TV)'],
#  'Shigatsu wa Kimi no Uso': ['Aru Machi Kado no Monogatari',
#   'Fuuka',
#   'Miyuki',
#   'Kaikan Phrase',
#   'Bronze: Zetsuai Since 1989',
#   'Zetsuai 1989',
#   'A-Girl',
#   'White Album 2',
#   'Wo Shi Jiang Xiaobai 2nd Season',
#   'Mudai'],
#  'Made in Abyss': ['Made in Abyss Movie 2: Hourou Suru Tasogare',
#   'Made in Abyss Movie 3: Fukaki Tamashii no Reimei',
#   'Jyu Oh Sei',
#   'Shoumetsu Toshi',
#   'Ginga Tansa 2100-nen: Border Planet',
#   'Karakuri Circus (TV)',
#   'Sign',
#   'R.O.D: Read or Die',
#   'Rescue Academia',
#   'Akai Koudan Zillion: Utahime Yakyoku'],
#  'Fullmetal Alchemist: Brotherhood': ['Fullmetal Alchemist: Brotherhood Specials',
#   'Kouya no Kotobuki Hikoutai',
#   'Kouya no Kotobuki Hikoutai Gaiden: Oozora no Harukaze Hikoutai',
#   'Gate: Jieitai Kanochi nite, Kaku Tatakaeri 2nd Season',
#   'Full Metal Panic! The Second Raid Episode 00',
#   'Majo no Takkyuubin',
#   'Zetsuen no Tempest',
#   'Uchuu Senkan Yamato: Fukkatsu-hen',
#   'Generation of Chaos Next: Chikai no Pendant',
#   'Sora no Momotarou'],
#  'Kizumonogatari III: Reiketsu-hen': ['Kizumonogatari II: Nekketsu-hen',
#   'Kizumonogatari I: Tekketsu-hen',
#   'Durarara!!x2 Ten',
#   'Durarara!!x2 Shou',
#   'Durarara!!x2 Ketsu',
#   'Durarara!!',
#   'Durarara!!x2 Shou: Watashi no Kokoro wa Nabe Moyou',
#   'Huangli Shi',
#   'Durarara!!x2 Ketsu: Dufufufu!!',
#   'Durarara!!x2 Ten: Onoroke Chakapoko'],
#  'Mob Psycho 100 II': ['Mob Psycho 100',
#   'Mob Psycho 100: Dai Ikkai Rei toka Soudansho Ian Ryokou - Kokoro Mitasu Iyashi no Tabi',
#   'Mob Psycho 100: Reigen - Shirarezaru Kiseki no Reinouryokusha',
#   'Flying Witch Petit',
#   'Fei Ren Zai',
#   'Tansu Warashi.',
#   'Haruniwa Ie no 3 Nin-me',
#   'Han Hua Ri Ji',
#   'Peeping Life x Kaijuu Sakaba Kaiji: Kaijuu-tachi ga Iru Tokoro',
#   'Dororonpa!'],
#  'Sen to Chihiro no Kamikakushi': ['Da Yu Hai Tang (Movie)',
#   'Himiko-den',
#   'JoJo no Kimyou na Bouken Part 3: Stardust Crusaders',
#   'JoJo no Kimyou na Bouken Part 3: Stardust Crusaders 2nd Season',
#   'Bleach: Memories in the Rain',
#   'Bakemono no Ko',
#   'Shinpi no Hou',
#   'Vampire Hunter',
#   'Momo e no Tegami',
#   'Asatte no Houkou.'],
#  'Kimetsu no Yaiba': ['Gambo',
#   'Chrno Crusade',
#   'Kujakuou: Sengoku Tensei',
#   'Onigakure Yama no Soba no Hana',
#   'Koutetsu Sangokushi Special',
#   'Toukiden: The Age of Demons - Introduction',
#   'Toukiden 2',
#   'Tokyo Ravens: Kon ga Oshiete Moshi Agemasu! Maru Wakari Tokyo Ravens',
#   'Shounen Tokugawa Ieyasu',
#   'Hadashi no Gen 2'],
#  'Owarimonogatari 2nd Season': ['Owarimonogatari',
#   'Owarimonogatari 2nd Season Recaps',
#   'Nyanpire The Animation',
#   'Hanamonogatari',
#   'Vampire Holmes',
#   'Vlad Love',
#   "Master Mosquiton '99",
#   'Tsukimonogatari',
#   'Nisemonogatari',
#   'Yichang Shengwu Jianwenlu'],
#  'Code Geass: Hangyaku no Lelouch R2': ['Code Geass: Fukkatsu no Lelouch',
#   'Code Geass: Hangyaku no Lelouch',
#   'Giant Robo the Animation: Chikyuu ga Seishi Suru Hi',
#   'Guilty Crown: Lost Christmas - An Episode of Port Town',
#   'Code Geass: Hangyaku no Lelouch I - Koudou',
#   'Double Circle',
#   'Shin Mazinger Shougeki! Z-hen',
#   'Guilty Crown',
#   'Bounen no Xamdou',
#   'Vexille: 2077 Nihon Sakoku'],
#  'Haikyuu!!: Karasuno Koukou vs. Shiratorizawa Gakuen Koukou': ['Haikyuu!!: Karasuno Koukou vs. Shiratorizawa Gakuen Koukou',
#   'Haikyuu!! Movie 2: Shousha to Haisha',
#   'Haikyuu!! Movie 1: Owari to Hajimari',
#   'Slam Dunk',
#   'Haikyuu!!',
#   'Haikyuu!!: To the Top',
#   'Haikyuu!!: Riku vs. Kuu',
#   'Ahiru no Sora',
#   'Slam Dunk: Zenkoku Seiha Da! - Sakuragi Hanamichi',
#   'Battle Athletess Daiundoukai (TV)'],
#  'Gintama.': ['Gintama',
#   "Gintama': Enchousen",
#   'Gintama: Shinyaku Benizakura-hen',
#   'Gintama.: Shirogane no Tamashii-hen - Kouhan-sen',
#   'Gintama°',
#   'Gintama°: Umai-mono wa Atomawashi ni Suru to Yokodorisareru kara Yappari Saki ni Kue',
#   'Gintama: Nanigoto mo Saiyo ga Kanjin nano de Tasho Senobisuru Kurai ga Choudoyoi',
#   'Tono to Issho 1.5',
#   'Tono to Issho',
#   'Tono to Issho: Gantai no Yabou'],
#  'Gintama Movie 2: Kanketsu-hen - Yorozuya yo Eien Nare': ["Gintama': Futon ni Haitte kara Buki Nokoshi ni Kizuite Neru ni Nerenai Toki mo Aru",
#   'Gintama: Yorinuki Gintama-san on Theater 2D',
#   'Gintama Movie 1: Shinyaku Benizakura-hen',
#   'Gintama.: Porori-hen',
#   'Gintama.: Shirogane no Tamashii-hen',
#   "Gintama'",
#   'Gintama: Nanigoto mo Saiyo ga Kanjin nano de Tasho Senobisuru Kurai ga Choudoyoi',
#   'Gintama°: Umai-mono wa Atomawashi ni Suru to Yokodorisareru kara Yappari Saki ni Kue',
#   'Gintama: Shiroyasha Koutan',
#   'Gintama (Shinsaku)'],
#  'Gintama': ['Gintama',
#   "Gintama': Enchousen",
#   'Gintama: Shinyaku Benizakura-hen',
#   'Gintama.: Shirogane no Tamashii-hen - Kouhan-sen',
#   'Gintama°',
#   'Gintama°: Umai-mono wa Atomawashi ni Suru to Yokodorisareru kara Yappari Saki ni Kue',
#   'Gintama: Nanigoto mo Saiyo ga Kanjin nano de Tasho Senobisuru Kurai ga Choudoyoi',
#   'Tono to Issho 1.5',
#   'Tono to Issho',
#   'Tono to Issho: Gantai no Yabou'],
#  'Clannad: After Story': ['Kokoro Connect',
#   'Fruits Basket',
#   'Kamichu! Specials',
#   'Hanada Shounen-shi',
#   'Little Busters!',
#   'Flying Witch Petit',
#   'Fei Ren Zai',
#   'Tansu Warashi.',
#   'Haruniwa Ie no 3 Nin-me',
#   'Han Hua Ri Ji'],
#  "Gintama': Enchousen": ['Gintama',
#   "Gintama': Enchousen",
#   'Gintama: Shinyaku Benizakura-hen',
#   'Gintama.: Shirogane no Tamashii-hen - Kouhan-sen',
#   'Gintama°',
#   'Gintama°: Umai-mono wa Atomawashi ni Suru to Yokodorisareru kara Yappari Saki ni Kue',
#   'Gintama: Nanigoto mo Saiyo ga Kanjin nano de Tasho Senobisuru Kurai ga Choudoyoi',
#   'Tono to Issho 1.5',
#   'Tono to Issho',
#   'Tono to Issho: Gantai no Yabou'],
#  'One Punch Man': ['One Punch Man: Road to Hero',
#   'One Punch Man 2nd Season Commemorative Special',
#   'One Punch Man 2nd Season Specials',
#   'Canaan',
#   'Himitsukessha Taka no Tsume NEO',
#   'Himitsukessha Taka no Tsume MAX',
#   'DC Super Heroes vs Taka no Tsume Dan',
#   'Himitsukessha Taka no Tsume The Movie 1: Soutou wa Nido Shinu',
#   'Himitsukessha Taka no Tsume The Movie II: Watashi wo Aishita Kuro Oolong-Cha',
#   'Himitsukessha Taka no Tsume Countdown'],
#  'Kaguya-hime no Monogatari': ['Tako no Hone',
#   'Kamishibai Kintarou no Maki',
#   'Kasa Jizou',
#   'Kitakaze no Kureta Table-kake',
#   'Umihiko Yamahiko',
#   'Yukidaruma',
#   'Manga Nippon Mukashibanashi (1976)',
#   'Anju to Zushioumaru',
#   'Tao Hua Yuan Ji',
#   'Greek Roman Sinhwa: Olympus Guardian (Movie)'],
#  'Koukaku Kidoutai 2.0': ['Koukaku Kidoutai: Shin Movie',
#   'Koukaku Kidoutai Arise: Ghost in the Shell - Border:2 Ghost Whispers',
#   'Koukaku Kidoutai Arise: Ghost in the Shell - Border:4 Ghost Stands Alone',
#   'Koukaku Kidoutai Arise: Ghost in the Shell - Border:1 Ghost Pain',
#   'Koukaku Kidoutai Arise: Ghost in the Shell - Border:3 Ghost Tears',
#   'Koukaku Kidoutai Arise: Alternative Architecture',
#   'Koukaku Kidoutai 2: Innocence',
#   'Psycho-Pass: Sinners of the System Case.3 - Onshuu no Kanata ni＿＿',
#   'Psycho-Pass 3 Movie: First Inspector',
#   'Psycho-Pass: Sinners of the System Case.2 - First Guardian'],
#  'Nodame Cantabile: Finale - Mine to Kiyora no Saikai': ['Nodame Cantabile: Finale',
#   'Nodame Cantabile: Paris-hen',
#   'Nodame Cantabile OVA',
#   'Sakamichi no Apollon',
#   'Servamp Specials',
#   'Karneval Specials',
#   'Koisuru Shirokuma Tokubetsu-ban',
#   'Kuragehime: Soreike! Amars Tankentai',
#   'Relationship Scramble feat. Hatsune Miku',
#   'White Tree'],
#  'Saraiya Goyou': ['Hidamari no Ki',
#   'Gosick',
#   'Kochouki: Wakaki Nobunaga',
#   'Hijikata Toshizou: Shiro no Kiseki',
#   'Takarajima',
#   'Kaumori',
#   'Fuyu no Semi Special',
#   'Kitsutsuki Tanteidokoro',
#   'Samuraider: Nazo no Tenkousei',
#   'Di Wang Gong Lue'],
#  'Saint Seiya: Meiou Hades Meikai-hen': ['Dragon Ball Movie 3: Makafushigi Daibouken',
#   'Dragon Ball Movie 2: Majinjou no Nemurihime',
#   'Dragon Ball Movie 4: Saikyou e no Michi',
#   'Doupo Cangqiong Specials',
#   'Doupo Cangqiong 2nd Season Specials',
#   "Eat-Man '98",
#   'Eat-Man',
#   'Black Cat',
#   'Chiisana Kyojin Microman: Daigekisen! Microman vs. Saikyou Senshi Gorgon',
#   'Dokkaebi Gamtu'],
#  'Noragami OVA': ['Noragami Aragoto OVA',
#   'Noragami',
#   'Noragami Aragoto',
#   'Yuu☆Yuu☆Hakusho: Eizou Hakusho II',
#   'Inu x Boku SS Special',
#   'Tuxedo Gin',
#   'Tonari no Totoro',
#   'Yuugen Kaisha: Jiken File 00 - Hajimari wa Ayashiku mo Hanayaka ni',
#   'Sakura Taisen: New York',
#   'Lily to Kaeru to (Otouto)'],
#  'Lupin III: Part II': ['Lupin III: Part 5',
#   'Lupin III: Cagliostro no Shiro',
#   'Lupin III: Ikiteita Majutsushi',
#   'Lupin III: Episode 0 "First Contact"',
#   'Lupin III: Sweet Lost Night - Mahou no Lamp wa Akumu no Yokan',
#   'Lupin III: Moeyo Zantetsuken!',
#   'Lupin III',
#   'Lupin III: Nusumareta Lupin',
#   'Lupin III: Tenshi no Tactics - Yume no Kakera wa Koroshi no Kaori',
#   'Lupin III: Harimao no Zaihou wo Oe!!'],
#  'Kobayashi-san Chi no Maid Dragon: Valentine, Soshite Onsen! - Amari Kitai Shinaide Kudasai': ['Kobayashi-san Chi no Maid Dragon',
#   'Wooser no Sono Higurashi: Ken to Pants to Wooser to',
#   'Kobayashi-san Chi no Maid Dragon 2nd Season',
#   'Dot Bit Retro: Boku Dake no Kusogee',
#   'Yousei Tin Tin',
#   'Wooser no Sono Higurashi',
#   'Kobayashi-san Chi no OO Dragon',
#   'Namiuchigiwa no Muromi-san',
#   'Namiuchigiwa no Muromi-san: Pangea Chou Tairiku no Muromi-san',
#   'Sora no Method: Mou Hitotsu no Negai'],
#  'Kuroko no Basket 2nd Season NG-shuu': ['Yuri!!! on Ice',
#   'Kuroko no Basket 3rd Season NG-shuu',
#   'Free!: FrFr - Short Movie',
#   'Yuri!!! on Ice The Movie: Ice Adolescence',
#   'Anitore! XX: Hitotsu Yane no Shita de',
#   'Anitore! EX',
#   'Nude Batter Tetsuo',
#   'Maabou no Daikyousou',
#   'Oira no Ski',
#   'Doubutsu Olympic Taikai'],
#  'K-On!: Live House!': ['K-On!!',
#   'K-On!!: Keikaku!',
#   'I★Chu: Étoile Stage',
#   'Love Live! School Idol Project 2nd Season',
#   'Love Live! The School Idol Movie',
#   'Love Live! Sunshine!! 2nd Season',
#   'Starmyu',
#   'Love Live! Sunshine!! The School Idol Movie: Over the Rainbow',
#   'Tenshi no 3P!',
#   'Omoide no Album'],
#  'K-On!': ['Hibike! Euphonium: Suisougaku-bu no Nichijou',
#   'K-On!: Live House!',
#   'K-On!!',
#   'K-On!!: Keikaku!',
#   'I★Chu: Étoile Stage',
#   'Gochuumon wa Usagi Desu ka??: Dear My Sister',
#   'Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??'],
#  'InuYasha Movie 3: Tenka Hadou no Ken': ['InuYasha Movie 2: Kagami no Naka no Mugenjo',
#   'InuYasha Movie 1: Toki wo Koeru Omoi',
#   'InuYasha Movie 4: Guren no Houraijima',
#   'InuYasha (TV)',
#   'InuYasha: Kanketsu-hen',
#   'Umi Monogatari: Anata ga Ite Kureta Koto',
#   'Tsubasa: Shunraiki',
#   'Chuan Shu Zijiu Zhinan',
#   'Tactics',
#   'Kuroshitsuji: Sono Shitsuji, Kougyou'],
#  'Hidamari Sketch x ☆☆☆ Specials': ['Hidamari Sketch x 365',
#   'Hidamari Sketch x ☆☆☆',
#   'Hidamari Sketch x Honeycomb',
#   'Hidamari Sketch: Sae Hiro Sotsugyou-hen',
#   'Hidamari Sketch x SP',
#   'Hidamari Sketch x 365 Specials',
#   'Houkago Teibou Nisshi',
#   'GA: Geijutsuka Art Design Class: Aozora ga Kakitai',
#   'Sakamoto Desu ga?',
#   'Hidamari Sketch Specials'],
#  'Haikyuu!! Movie 2: Shousha to Haisha': ['Haikyuu!!: Karasuno Koukou vs. Shiratorizawa Gakuen Koukou',
#   'Haikyuu!! Movie 2: Shousha to Haisha',
#   'Haikyuu!! Movie 1: Owari to Hajimari',
#   'Slam Dunk',
#   'Haikyuu!!',
#   'Haikyuu!!: To the Top',
#   'Haikyuu!!: Riku vs. Kuu',
#   'Ahiru no Sora',
#   'Slam Dunk: Zenkoku Seiha Da! - Sakuragi Hanamichi',
#   'Battle Athletess Daiundoukai (TV)'],
#  'Gochuumon wa Usagi Desu ka??: Dear My Sister': ['Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??',
#   'Yuru Camp△',
#   'Gochuumon wa Usagi Desu ka??: Sing for You',
#   'Aggressive Retsuko (ONA)',
#   'Jungle wa Itsumo Hare nochi Guu Final',
#   'Sora yori mo Tooi Basho: Yokoku',
#   'Choboraunyopomi Gekijou Dai San Maku Ai Mai Mii: Surgical Friends'],
#  'Ginga Eiyuu Densetsu: Die Neue These - Seiran 1': ['Uchuu Senkan Yamato 2202: Ai no Senshi-tachi',
#   'Terra e... (TV)',
#   'Ginga Eiyuu Densetsu: Die Neue These - Seiran 2',
#   'Ginga Eiyuu Densetsu: Arata Naru Tatakai no Overture',
#   'Ginga Eiyuu Densetsu: Die Neue These - Seiran 3',
#   'Uchuu Senkan Yamato 2199',
#   'Ginga Eiyuu Densetsu: Die Neue These - Kaikou',
#   'Ouritsu Uchuugun: Honneamise no Tsubasa',
#   'Uchuu Kuubo Blue Noah',
#   'Halo Legends'],
#  'Gekkan Shoujo Nozaki-kun Specials': ['Gekkan Shoujo Nozaki-kun',
#   'Yahari Ore no Seishun Love Comedy wa Machigatteiru. Zoku OVA',
#   'Seishun Buta Yarou wa Yumemiru Shoujo no Yume wo Minai',
#   'Kujibiki Unbalance',
#   'Ore wo Suki nano wa Omae dake ka yo: Oretachi no Game Set',
#   'Kud Wafter',
#   'School Days: Valentine Days',
#   'Kare Baka: Wagahai no Kare wa Baka de R',
#   'Yonhyaku-nijuu Renpai Girl',
#   'Gamers!'],
#  'Gate: Jieitai Kanochi nite, Kaku Tatakaeri 2nd Season': ['Kouya no Kotobuki Hikoutai',
#   'Kouya no Kotobuki Hikoutai Gaiden: Oozora no Harukaze Hikoutai',
#   'Full Metal Panic! The Second Raid Episode 00',
#   'Generation of Chaos Next: Chikai no Pendant',
#   'Uchuu Senkan Yamato: Fukkatsu-hen',
#   'Area 88',
#   'Area 88 Movie',
#   'Tide-Line Blue',
#   'Golgo 13',
#   'Sora no Momotarou'],
#  'Doukyonin wa Hiza, Tokidoki, Atama no Ue.': ['Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??',
#   'Yuru Camp△',
#   'Gochuumon wa Usagi Desu ka??: Sing for You',
#   'Aggressive Retsuko (ONA)',
#   'Jungle wa Itsumo Hare nochi Guu Final',
#   'Sora yori mo Tooi Basho: Yokoku',
#   'Choboraunyopomi Gekijou Dai San Maku Ai Mai Mii: Surgical Friends'],
#  'Digimon Adventure': ['Pokemon: The Origin',
#   'Pokemon Crystal: Raikou Ikazuchi no Densetsu',
#   'Pokemon Best Wishes! Season 2: Decolora Adventure - Dent to Takeshi! Gyarados no Gekirin!!',
#   'Pokemon Best Wishes! Season 2: Decolora Adventure - Iris vs. Ibuki! Dragon Master e no Michi!!',
#   'Pokemon Best Wishes!',
#   'Pokemon Movie 22: Mewtwo no Gyakushuu Evolution',
#   'Pokemon Best Wishes! Season 2',
#   'Pokemon Diamond & Pearl: Clip Show',
#   'Pokemon XY: New Year Special',
#   "Pokemon XY: New Year's Eve 2014 Super Mega Special"],
#  'Byousoku 5 Centimeter': ['Josee to Tora to Sakana-tachi',
#   'Fune wo Amu',
#   'Omoide Poroporo',
#   'Just Because!',
#   'Eine Kleine',
#   'Furiko',
#   'Peach Girl',
#   'Bokura ga Ita',
#   'Kimi no Iru Machi OVA',
#   'Kimi no Iru Machi'],
#  'Detective Conan OVA 10: Kid in Trap Island': ['Detective Conan OVA 09: The Stranger in 10 Years...',
#   'Detective Conan Movie 15: Quarter of Silence',
#   'Detective Conan Movie 10: Requiem of the Detectives',
#   'Detective Conan Movie 17: Private Eye in the Distant Sea',
#   'Detective Conan vs. Wooo',
#   'Detective Conan Movie 11: Jolly Roger in the Deep Azure',
#   'Detective Conan: Conan vs. Kid - Jet Black Sniper',
#   'Detective Conan Movie 16: The Eleventh Striker',
#   'Detective Conan Bonus File: Fantasista Flower',
#   'Detective Conan Movie 06: The Phantom of Baker Street'],
#  'Bungou Stray Dogs: Dead Apple': ['Tiger & Bunny: Too Many Cooks Spoil the Broth.',
#   'Futari wa Milky Holmes',
#   'Tantei Opera Milky Holmes: Summer Special',
#   'Tantei Opera Milky Holmes',
#   'Tantei Opera Milky Holmes: Arsene Karei naru Yokubou',
#   'Tantei Opera Milky Holmes: Alternative',
#   'Tantei Kageki Milky Holmes TD',
#   'Tantei Opera Milky Holmes Dai 2 Maku',
#   'Tantei Opera Milky Holmes Movie: Gyakushuu no Milky Holmes',
#   'Souryuuden'],
#  'Asagao to Kase-san.': ['Yagate Kimi ni Naru',
#   'Candy Boy: Nonchalant Talk of the Certain Twin Sisters in Daily Life',
#   'Candy☆Boy: Side Story For Archive',
#   'Sasameki Koto',
#   'Sono Hanabira ni Kuchizuke wo: Reo x Mai Diaries',
#   'Citrus',
#   'Strawberry Panic',
#   'Kimi no Hikari: Asagao to Kase-san.',
#   'Adachi to Shimamura',
#   'Akuma no Riddle'],
#  'Ansatsu Kyoushitsu 2nd Season: Kagaijugyou-hen': ['Ansatsu Kyoushitsu',
#   'Ansatsu Kyoushitsu 2nd Season',
#   'Busou Shoujo Machiavellianism',
#   'Ansatsu Kyoushitsu: 365-nichi no Jikan',
#   'Ansatsu Kyoushitsu: Deai no Jikan',
#   'Udauda Yatteru Hima wa Nee!',
#   'Tennis no Ouji-sama: Best Games!!',
#   'Full Metal Panic? Fumoffu',
#   'Cheating Craft',
#   'Shonan Junai Gumi!'],
#  'Yaoguai Mingdan 2nd Season': ['Baito-saki wa "Aku no Soshiki"!?',
#   'Ore, Twintail ni Narimasu.',
#   'El Hazard: The Wanderers',
#   'Dame x Prince Anime Caravan',
#   'Tales of Eternia The Animation',
#   'Hidan no Aria',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka III',
#   'Hitsugi no Chaika: Avenging Battle',
#   'Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka II'],
#  'Uchuu Senkan Yamato 2202: Ai no Senshi-tachi': ['Uchuu Senkan Yamato 2202: Ai no Senshi-tachi',
#   'Terra e... (TV)',
#   'Ginga Eiyuu Densetsu: Die Neue These - Seiran 2',
#   'Ginga Eiyuu Densetsu: Arata Naru Tatakai no Overture',
#   'Ginga Eiyuu Densetsu: Die Neue These - Seiran 3',
#   'Uchuu Senkan Yamato 2199',
#   'Ginga Eiyuu Densetsu: Die Neue These - Kaikou',
#   'Ouritsu Uchuugun: Honneamise no Tsubasa',
#   'Uchuu Kuubo Blue Noah',
#   'Halo Legends'],
#  'Transformers the Movie': ['M3: Sono Kuroki Hagane Recap',
#   'Benghuai 3: Reburn',
#   'Project HAL',
#   'Giant Robo',
#   'Mobile Suit Gundam UC: A Phantom World',
#   'Kyouryuu Daisensou Izenborg',
#   'Tetsujin 28-gou (1980)',
#   'Chuunibyou demo Koi ga Shitai!: Depth of Field - Ai to Nikushimi Gekijou',
#   'Grendizer Giga',
#   'Macross XX'],
#  'Toshokan Sensou: Kakumei no Tsubasa': ['Aozora Shoujo-tai',
#   'Code Geass: Boukoku no Akito 2 - Hikisakareshi Yokuryuu Picture Drama',
#   'Tactical Roar',
#   'Upotte!!',
#   'Code Geass: Boukoku no Akito 3 - Kagayaku Mono Ten yori Otsu Picture Drama',
#   'Fuku-chan no Sensuikan',
#   'Toaru Hikuushi e no Tsuioku',
#   'Senjou no Valkyria',
#   'Tactical Roar Special',
#   'Fullmetal Alchemist: Brotherhood - 4-Koma Theater'],
#  'Shokugeki no Souma: Shin no Sara': ['Shokugeki no Souma: San no Sara - Tootsuki Ressha-hen',
#   'Shokugeki no Souma: San no Sara',
#   'Shokugeki no Souma: Ni no Sara',
#   'Shokugeki no Souma',
#   'Shokugeki no Souma: Gou no Sara',
#   'Shokugeki no Souma: Ni no Sara OVA',
#   'Shokugeki no Souma OVA',
#   'Triage X: Recollection XOXO',
#   'Hatsukoi Limited.: Gentei Shoujo',
#   'Ane Log: Moyako Neesan no Tomaranai Monologue'],
#  'Paradise Kiss': ['Hachimitsu to Clover',
#   'Hachimitsu to Clover Specials',
#   'Hachimitsu to Clover II',
#   'Ristorante Paradiso',
#   "Rouge: Lady's Comic Video",
#   'Massugu ni Ikou.',
#   'Nodame Cantabile: Nodame to Chiaki no Umi Monogatari',
#   'Sagashita no wa Oheya, Mitsuketa no wa Mirai',
#   'Hai! Akko Desu',
#   'Megumi to Taiyou: Kajuu Gummi Tweet Love Story'],
#  'Manga de Wakaru! Fate/Grand Order': ['Full Metal Panic! The Second Raid: Wari to Hima na Sentaichou no Ichinichi',
#   'Hentatsu',
#   'Wake Up, Girl Zoo!',
#   'Chinpui: Eri-sama Katsudou Daishashin',
#   'Ben-To Picture Drama',
#   'Neko Ramen: Ore no Shouyu Aji',
#   "What's Michael? 2",
#   'Noraneko',
#   'Koneko no Studio',
#   "Robber's Company"],
#  'Lucky☆Star: Original na Visual to Animation': ['Tesagure! Bukatsumono Spin-off Purupurun Sharumu to Asobou',
#   'Tesagure! Bukatsumono',
#   'Tesagure! Bukatsumono Encore',
#   'Binan Koukou Chikyuu Boueibu Happy Kiss!',
#   'Petit Eva: Evangelion@School',
#   'Chen-Kuro Gakuen',
#   'Seto no Hanayome Fan Disc',
#   'Kuro-Nikuru Girls',
#   'Seto no Hanayome OVA Specials',
#   'Sayonara Zetsubou Sensei Jo: Zoku Zetsubou Shoujo Senshuu'],
#  'Last Exile': ['Beast Wars Second Chou Seimeitai Transformers: Lio Convoy Kiki Ippatsu! Movie',
#   'Ozma',
#   'Zero Seiki Movie 3: Maetel',
#   'Zero Seiki Movie 2: Herlock',
#   'Zero Seiki Movie 1: Emeraldas',
#   'Shinzou Ningen Casshern',
#   'Hyper-Psychic Geo Garaga',
#   'Pastel Memories',
#   'Super Child',
#   'Medarot Damashii'],
#  'Koukaku Kidoutai 2: Innocence': ['Koukaku Kidoutai Arise: Ghost in the Shell - Border:2 Ghost Whispers',
#   'Koukaku Kidoutai Arise: Ghost in the Shell - Border:4 Ghost Stands Alone',
#   'Koukaku Kidoutai Arise: Ghost in the Shell - Border:1 Ghost Pain',
#   'Koukaku Kidoutai Arise: Ghost in the Shell - Border:3 Ghost Tears',
#   'Koukaku Kidoutai Arise: Alternative Architecture',
#   'Koukaku Kidoutai: Shin Movie',
#   'Koukaku Kidoutai 2.0',
#   'Psycho-Pass: Sinners of the System Case.3 - Onshuu no Kanata ni＿＿',
#   'Psycho-Pass 3 Movie: First Inspector',
#   'Psycho-Pass: Sinners of the System Case.2 - First Guardian'],
#  'Heartcatch Precure!': ['Fresh Precure!',
#   'Onegai! Samia Don',
#   'Shin Kimagure Orange☆Road: Soshite, Ano Natsu no Hajimari',
#   'Mahou Gakuen Lunar! Aoi Ryuu no Himitsu',
#   'Zettai Bouei Leviathan: Mini Takibi Gekijou',
#   'Onegai My Melody Sukkiri♪',
#   'Onegai♪My Melody Kirara★',
#   'Zettai Bouei Leviathan',
#   'Onegai My Melody: Kuru Kuru Shuffle!',
#   'Honzuki no Gekokujou: Shisho ni Naru Tame ni wa Shudan wo Erandeiraremasen'],
#  'Hidamari Sketch x 365': ['Hidamari Sketch x 365',
#   'Hidamari Sketch x ☆☆☆',
#   'Hidamari Sketch x Honeycomb',
#   'Hidamari Sketch: Sae Hiro Sotsugyou-hen',
#   'Hidamari Sketch x SP',
#   'Hidamari Sketch x 365 Specials',
#   'Houkago Teibou Nisshi',
#   'GA: Geijutsuka Art Design Class: Aozora ga Kakitai',
#   'Sakamoto Desu ga?',
#   'Hidamari Sketch Specials'],
#  'Ginga Tetsudou 999': ['Ginga Tetsudou 999 (ONA)',
#   'Sayonara Ginga Tetsudou 999: Andromeda Shuuchakueki',
#   'Ginga Tetsudou 999 (Movie)',
#   'Uchuu Kaizoku Captain Herlock: Arcadia-gou no Nazo',
#   'Odin: Koushi Hansen Starlight',
#   'Young Herlock wo Oe! Cosmo Warrior Zero Gaiden',
#   'MAPS: Densetsu no Samayoeru Seijin-tachi',
#   'After War Gundam X',
#   'Uchuu Senkan Yamato 2',
#   'Uchuu Senkan Yamato: Kanketsu-hen'],
#  'Gundam Build Fighters': ['Koukaku Kidoutai: Stand Alone Complex 2nd GIG - Individual Eleven',
#   'Evangelion: 2.0 You Can (Not) Advance',
#   'Choujuu Kishin Dancougar: Juusenki-tai Songs',
#   'SSSS.Dynazenon',
#   'Mecha-ude',
#   'Hoshi to Tsubasa no Paradox',
#   'All That Gundam',
#   'Babel Nisei (OVA)',
#   'Dallos',
#   'Regalia: The Three Sacred Stars'],
#  'Ghost Hunt': ['Zonmi-chan: Meat Pie of the Dead',
#   'Tezuka Osamu no Don Dracula',
#   'Chainsaw Maid Episode 0',
#   'Chainsaw Maid',
#   'Chainsaw Bunny',
#   'Mayoiga',
#   'Gegege no Kitarou (1968)',
#   'Gegege no Kitarou (1968 Movie)',
#   'Kaibutsu Oujo Specials',
#   'Kaibutsu Oujo (OVA)'],
#  'Gakuen Babysitters': ['Nijiiro Days OVA',
#   'Nijiiro Days',
#   'Watashi no Ashinaga Ojisan Specials',
#   'Aikatsu Stars!',
#   'Aikatsu!',
#   'Aikatsu Stars! Movie',
#   'Ao Haru Ride',
#   'Kareshi Kanojo no Jijou',
#   'Princess Princess',
#   'Nanairo Kakumei'],
#  'Detective Conan Movie 23: The Fist of Blue Sapphire': ['City Hunter: Ryou no Propose',
#   'Detective Conan: The Bomb Demon That Came From the Picture Book',
#   'Detective Conan: Amuro Secret Call',
#   'Hidan no Aria: Butei ga Kitarite Onsen Kenshuu',
#   'Clamp Gakuen Tanteidan',
#   'Meitantei Holmes',
#   'City Hunter Movie: Shinjuku Private Eyes',
#   'Detective Conan Movie 09: Strategy Above the Depths',
#   'Detective Conan Movie 07: Crossroad in the Ancient Capital',
#   'Detective Conan Movie 01: The Timed Skyscraper'],
#  'Bleach': ['Bleach Movie 4: Jigoku-hen',
#   'Bleach: The Sealed Sword Frenzy',
#   'Bleach Movie 3: Fade to Black - Kimi no Na wo Yobu',
#   'Bleach Movie 2: The DiamondDust Rebellion - Mou Hitotsu no Hyourinmaru',
#   'Bleach Movie 1: Memories of Nobody',
#   'Yuugen Kaisha',
#   'Esper Mami Special: My Angel Mami-chan',
#   'Tokyo ESP',
#   'Ueki no Housoku',
#   'Zettai Karen Children: The Unlimited - Hyoubu Kyousuke'],
#  'Akagami no Shirayuki-hime': ['Fushigi Yuugi: Eikouden',
#   'Kurumiwari Ningyou (2014)',
#   'Legend of Basara',
#   'Oh! Family',
#   'Nineteen 19',
#   "I''s",
#   'Refrain Blue',
#   'Memories Off',
#   'Shin Dousei Jidai: Hawaiian Breeze',
#   'Memories Off 2nd'],
#  '91 Days': ['Fuse: Teppou Musume no Torimonochou',
#   'Bakumatsu Kikansetsu Irohanihoheto',
#   'Boy General',
#   'Kyokujitsu no Kantai',
#   'Konpeki no Kantai',
#   'Basilisk: Ouka Ninpouchou',
#   'Angolmois: Genkou Kassenki',
#   'Flanders no Inu (Movie)',
#   'Hotaru no Haka',
#   'Hadashi no Gen'],
#  "Wolf's Rain": ['Made in Abyss Movie 1: Tabidachi no Yoake',
#   'Concrete Revolutio: Choujin Gensou',
#   'Ginga Tetsudou no Yoru: Fantasy Railroad in the Stars Special',
#   'Ginga Tetsudou no Yoru: Fantasy Railroad in the Stars',
#   'Saiyuuki Gaiden',
#   'Tate no Yuusha no Nariagari',
#   'Hai to Gensou no Grimgar',
#   'Tate no Yuusha no Nariagari 3rd Season',
#   'Tate no Yuusha no Nariagari 2nd Season',
#   'Wan Wan Chuushingura'],
#  'Tentai Senshi Sunred': ['Himitsukessha Taka no Tsume NEO',
#   'Himitsukessha Taka no Tsume MAX',
#   'DC Super Heroes vs Taka no Tsume Dan',
#   'Himitsukessha Taka no Tsume The Movie 1: Soutou wa Nido Shinu',
#   'Himitsukessha Taka no Tsume The Movie II: Watashi wo Aishita Kuro Oolong-Cha',
#   'Himitsukessha Taka no Tsume Countdown',
#   'Himitsukessha Taka no Tsume The Movie 3: http://takanotsume.jp wa Eien ni',
#   'DC Super Heroes vs Taka no Tsume Dan Promotion Eizou',
#   'Taka no Tsume NEO Announcement Movie',
#   'GJ8man Soushuuhen'],
#  'Shingeki no Kyojin OVA': ['Shingeki no Kyojin Movie 2: Jiyuu no Tsubasa',
#   "Aquarian Age: Saga II - Don't Forget Me...",
#   'Kouryuu no Mimi: Mina no Shou',
#   'One Piece: Episode of East Blue - Luffy to 4-nin no Nakama no Daibouken',
#   'One Piece Movie 14: Stampede',
#   'One Piece',
#   'One Piece: Episode of Sabo - 3 Kyoudai no Kizuna Kiseki no Saikai to Uketsugareru Ishi',
#   'One Piece: Long Ring Long Land-hen',
#   'One Piece: Episode of Sorajima',
#   'Shingeki no Kyojin'],
#  'Maria-sama ga Miteru 4th': ['Maria-sama ga Miteru Specials',
#   'Candy Boy Episode: EX01 - Mirai Yohouzu',
#   'Maria-sama ga Miteru: Haru',
#   'Yuru Yuri San☆Hai!',
#   'Maria-sama ga Miteru 3rd',
#   'Sono Hanabira ni Kuchizuke wo: Risa x Miya Gekijou',
#   'Yuru Yuri Nachuyachumi!',
#   'Watashi ni Tenshi ga Maiorita!',
#   'Oniisama e...',
#   'Aoi Hana'],
#  'Kubikiri Cycle: Aoiro Savant to Zaregototsukai': ['Vatican Kiseki Chousakan',
#   'Vatican Kiseki Chousakan: Majo no Soup',
#   'Durarara!!x2 Ten',
#   'Durarara!!x2 Shou',
#   'Durarara!!x2 Ketsu',
#   'Durarara!!',
#   'Durarara!!x2 Shou: Watashi no Kokoro wa Nabe Moyou',
#   'Huangli Shi',
#   'Durarara!!x2 Ketsu: Dufufufu!!',
#   'Durarara!!x2 Ten: Onoroke Chakapoko'],
#  'Kono Subarashii Sekai ni Shukufuku wo!: Kono Subarashii Choker ni Shukufuku wo!': ['Kono Subarashii Sekai ni Shukufuku wo! 2: Kono Subarashii Geijutsu ni Shukufuku wo!',
#   'Shakugan no Shana: Friagne to Marianne no Naze Nani Shana! Nandemo Shitsumonbako! 2',
#   'Umi Monogatari: Anata ga Ite Kureta Koto - Shinjiau Kokoro',
#   'Shakugan no Shana: Shana & Yuuji no Naze Nani Shana! Nandemo Shitsumon-bako!',
#   'Gegege no Kitarou: Jigoku-hen',
#   'Gegege no Kitarou: Youkai Daisensou',
#   'Ai to Ken no Camelot: Mangaka Marina Time Slip Jiken',
#   'Trip Trek',
#   'Jibaku-kun',
#   'Trip Trek (2010)'],
#  'Karakai Jouzu no Takagi-san': ['Free!: Eternal Summer - Kindan no All Hard!',
#   'Ani ni Tsukeru Kusuri wa Nai! 2',
#   'Minami-ke Tadaima',
#   'Ichigo Mashimaro OVA',
#   'Musashino!',
#   'Azumanga Daioh: Gekijou Tanpen',
#   'Watashi ga Motenai no wa Dou Kangaetemo Omaera ga Warui!: Motenaishi, Nazomeite Miru',
#   'Rifle Is Beautiful Recap',
#   'Slow Start',
#   'Joshikausei'],
#  'Junjou Romantica': ['Sekaiichi Hatsukoi',
#   'Junjou Romantica OVA',
#   'Junjou Romantica 3',
#   'Junjou Romantica 2',
#   'Sekaiichi Hatsukoi OVA',
#   'Sekaiichi Hatsukoi Movie: Yokozawa Takafumi no Baai',
#   'Sekaiichi Hatsukoi 2',
#   'Sekaiichi Hatsukoi: Propose-hen',
#   'Dakaretai Otoko 1-i ni Odosarete Imasu.',
#   'Ten Count'],
#  'Fate/Grand Order: Zettai Majuu Sensen Babylonia': ['Fate/stay night: Unlimited Blade Works Prologue',
#   'Fate/stay night: Unlimited Blade Works',
#   "Fate/stay night Movie: Heaven's Feel - I. Presage Flower",
#   'Fate/stay night: Unlimited Blade Works 2nd Season',
#   "Fate/stay night Movie: Heaven's Feel - II. Lost Butterfly",
#   'Fate/stay night: Unlimited Blade Works 2nd Season - Sunny Day',
#   'Fate/stay night Movie: Unlimited Blade Works',
#   'Mahou Sensou',
#   'Dragon Slayer Eiyuu Densetsu: Ouji no Tabidachi',
#   'Precure Super Stars! Movie'],
#  'Emiya-san Chi no Kyou no Gohan': ['Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??',
#   'Yuru Camp△',
#   'Gochuumon wa Usagi Desu ka??: Sing for You',
#   'Aggressive Retsuko (ONA)',
#   'Jungle wa Itsumo Hare nochi Guu Final',
#   'Sora yori mo Tooi Basho: Yokoku',
#   'Choboraunyopomi Gekijou Dai San Maku Ai Mai Mii: Surgical Friends'],
#  'Charlotte': ['Baka to Test to Shoukanjuu: Matsuri',
#   'Baka to Test to Shoukanjuu Mini Anime',
#   'Baka to Test to Shoukanjuu',
#   'Baka to Test to Shoukanjuu: Spinout! Sore ga Bokura no Nichijou',
#   'Mini Hama: Minimum Hamatora Movies',
#   'Toaru Kagaku no Accelerator',
#   'Code Geass: Hangyaku no Lelouch Recaps',
#   'Timing (Movie)',
#   'Esper Mami',
#   'Charlotte: Tsuyoimono-tachi'],
#  'Capeta': ["Bakusou Kyoudai Let's & Go MAX",
#   'Gekisou! Rubenkaiser',
#   'Crush Gear Nitro',
#   "Bakusou Kyoudai Let's & Go!! WGP Bousou Mini Yonku Daitsuiseki",
#   "Bakusou Kyoudai Let's & Go Special",
#   'Futari no Joe',
#   'Over Drive',
#   'Field ni Soyogu Kaze',
#   'Dokgotak Dasi Chajeun Maundeu',
#   'Gekitou! Crush Gear Turbo: Kaizabaan no Chousen'],
#  'Break Blade 5: Shisen no Hate': ['Break Blade 6: Doukoku no Toride',
#   'Break Blade',
#   'Senjou no Valkyria 3: Tagatame no Juusou',
#   'NG Knight Ramune & 40',
#   'Maze☆Bakunetsu Jikuu (TV)',
#   'NG Knight Ramune & 40 EX: Biku Biku Triangle Ai no Arashi Daisakusen',
#   'Maze☆Bakunetsu Jikuu: Tenpen Kyoui no Giant',
#   'Maze☆Bakunetsu Jikuu',
#   'VS Knight Lamune & 40 Fire',
#   'KO Seiki Beast Sanjuushi'],
#  'Aggressive Retsuko (ONA) 2nd Season': ['Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??',
#   'Yuru Camp△',
#   'Gochuumon wa Usagi Desu ka??: Sing for You',
#   'Aggressive Retsuko (ONA)',
#   'Jungle wa Itsumo Hare nochi Guu Final',
#   'Sora yori mo Tooi Basho: Yokoku',
#   'Choboraunyopomi Gekijou Dai San Maku Ai Mai Mii: Surgical Friends'],
#  'Yao Shen Ji 3rd Season': ['Wan Jie Xian Zong',
#   'Doupo Cangqiong Specials',
#   'Doupo Cangqiong 2nd Season Specials',
#   'Izumo: Takeki Tsurugi no Senki',
#   'Na Sa Er Ding',
#   'Tenjouhen: Utsunomiko',
#   'Yuki',
#   'Utsunomiko',
#   'Utsunomiko: Heaven Chapter',
#   'Generation of Chaos'],
#  'Space☆Dandy': ['Seihou Tenshi Angel Links: Meifon no Special Kaisetsu Corner',
#   'Crayon Shin-chan Gaiden: Alien vs. Shinnosuke',
#   'Musekinin Kanchou Tylor',
#   'Musekinin Galaxy☆Tylor',
#   '2020 Nyeon Ujuui Wonder Kiddy',
#   'Moonrise',
#   'Dai Yamato Zero-gou',
#   'Ginga Tetsudou 999: Eien no Tabibito Emeraldas',
#   'Uchuu no Hou: Reimei-hen',
#   'UFO Gakuen no Himitsu'],
#  'Slayers Try': ['Slayers Next',
#   'Slayers',
#   'Dragon Quest: Dai no Daibouken',
#   'Makai Senki Disgaea: Welcome to Netherworld',
#   'Dragon Quest: Dai no Daibouken (TV)',
#   'Slayers Excellent',
#   'Dragon Quest: Your Story',
#   'Ochi Mono RPG Seikishi Luvilias',
#   'Onna Maou Melissa no H na Boukenki',
#   'Mugyutto! Black Clover'],
#  'Seikai no Senki II': ['Seikai no Senki',
#   'Seikai no Senki III',
#   'Seikai no Senki Special',
#   'Seikai no Monshou Special',
#   'Seikai no Danshou: Tanjou',
#   'Mahoromatic: Automatic Maiden',
#   'Senjou no Valkyria',
#   'Kumo no Mukou, Yakusoku no Basho',
#   'Macross Plus',
#   'Mobile Suit Gundam SEED'],
#  'Mobile Suit Gundam Wing: Endless Waltz Movie': ['Soukou Kihei Votoms',
#   'Uchuu no Kishi Tekkaman Blade II',
#   'Taiyou no Kiba Dagram',
#   "Dennou Sentai Voogie's★Angel",
#   'Mobile Suit Gundam SEED Special Edition',
#   'Soliton no Akuma',
#   'Zone of the Enders: 2167 Idolo',
#   'Mobile Suit Gundam SEED Destiny Special Edition',
#   'Mobile Suit Gundam ZZ',
#   'Aoki Ryuusei SPT Layzner OVA'],
#  'Kyou kara Maou! 3rd Series': ['Kyou kara Maou!',
#   'Kyou kara Maou! R',
#   'Hong Haier: Juezhan Huoyanshan',
#   'Majutsushi Orphen',
#   'Beelzebub-jou no Okinimesu mama.',
#   'InuYasha: Kuroi Tessaiga',
#   'Dragon Ball Z Movie 10: Kiken na Futari! Super Senshi wa Nemurenai',
#   'Akuma Tou no Prince: Mitsume ga Tooru',
#   'Makai Senki Disgaea',
#   'Hoozuki no Reitetsu 2nd Season: Sono Ni'],
#  'Kokoro Connect': ['Clannad: After Story',
#   'Fruits Basket',
#   'Kamichu! Specials',
#   'Aura: Maryuuin Kouga Saigo no Tatakai',
#   'Little Busters!',
#   'Hanada Shounen-shi',
#   'Flying Witch Petit',
#   'Fei Ren Zai',
#   'Tansu Warashi.',
#   'Haruniwa Ie no 3 Nin-me'],
#  'Jungle wa Itsumo Hare nochi Guu Deluxe': ['Barakamon',
#   "Chi's Sweet Home",
#   'Ichigo Mashimaro Encore',
#   'Turning Girls',
#   'Yuru Camp△ Movie',
#   'Yuru Camp△ 2nd Season',
#   'Mangirl!',
#   'Peeping Life TV: Season 1??',
#   'Kotowaza House',
#   'Itoshi no Muco OVA'],
#  'Hybrid Child': ['Koutetsu Tenshi Kurumi Encore',
#   'Togainu no Chi',
#   'Kaze Tachinu',
#   'Genji Monogatari Sennenki',
#   'Genji Monogatari',
#   'Fushigi no Umi no Nadia',
#   'Hana no Kage',
#   'Eiyuu Banka Koushi-den',
#   'Shin Chou Kyou Ryo: Condor Hero II',
#   'Shin Chou Kyou Ryo: Condor Hero'],
#  'Hakuouki Movie 2: Shikon Soukyuu': ['Hakuouki Movie 1: Kyoto Ranbu',
#   'Hakuouki Reimeiroku',
#   'Hakuouki',
#   'Hakuouki OVA',
#   'Hakuouki Hekketsuroku Episode 0',
#   'Kamishibai Itazura Tanuki no Maki',
#   'Fate/Apocrypha Recaps',
#   'Sirius',
#   'Honoo no Mirage',
#   'Honoo no Mirage: Muyou no Michi'],
#  'Haikyuu!! Movie 1: Owari to Hajimari': ['Haikyuu!!: Karasuno Koukou vs. Shiratorizawa Gakuen Koukou',
#   'Haikyuu!! Movie 2: Shousha to Haisha',
#   'Haikyuu!! Movie 1: Owari to Hajimari',
#   'Slam Dunk',
#   'Haikyuu!!',
#   'Haikyuu!!: To the Top',
#   'Haikyuu!!: Riku vs. Kuu',
#   'Ahiru no Sora',
#   'Slam Dunk: Zenkoku Seiha Da! - Sakuragi Hanamichi',
#   'Battle Athletess Daiundoukai (TV)'],
#  'Gungrave': ['Ultraman',
#   'Infini-T Force Movie: Gatchaman - Saraba Tomo yo',
#   'Shangri-La',
#   'Buki yo Saraba',
#   'Altered Carbon: Resleeved',
#   'The Animatrix',
#   'One Punch Man Specials',
#   'One Punch Man 2nd Season',
#   'Gancheopjamneun Ttorijanggun',
#   'Ginga Tetsudou 999: Eternal Fantasy'],
#  'Goku Sayonara Zetsubou Sensei': ['Zan Sayonara Zetsubou Sensei',
#   'Sayonara Zetsubou Sensei',
#   'Zan Sayonara Zetsubou Sensei Bangaichi',
#   'Shingeki! Kyojin Chuugakkou',
#   'Gakuen Handsome Special',
#   'Gakuen Handsome The Animation',
#   'Gakuen Handsome',
#   'Petit Eva: Evangelion@School',
#   'Chen-Kuro Gakuen',
#   'Seto no Hanayome Fan Disc'],
#  'Ginga Eiyuu Densetsu Gaiden (1999)': ['Starship Operators',
#   'Ginga Patrol PJ',
#   'Ginga Eiyuu Densetsu: Die Neue These - Seiran 1',
#   'Uchuu Senkan Yamato 2202: Ai no Senshi-tachi',
#   'Terra e... (TV)',
#   'Ginga Eiyuu Densetsu: Die Neue These - Seiran 2',
#   'Ginga Eiyuu Densetsu: Arata Naru Tatakai no Overture',
#   'Ginga Eiyuu Densetsu: Die Neue These - Seiran 3',
#   'Uchuu Senkan Yamato 2199',
#   'Ginga Eiyuu Densetsu: Die Neue These - Kaikou'],
#  'Douluo Dalu': ['Mang Huang Ji',
#   'Xi Xing Ji',
#   'Si Hai Jing Qi',
#   'Fushigi Yuugi: Dai Ni Bu',
#   'Wan Jie Xian Zong',
#   'Katanagatari',
#   'Wu Shan Wu Xing',
#   'Qin Shi Ming Yue: Tian Xing Jiu Ge',
#   'Guan Hai Ce',
#   'Kogane no Hana'],
#  'Code Geass: Hangyaku no Lelouch R2 Special Edition - Zero Requiem': ['Code Geass: Hangyaku no Lelouch Special Edition - Black Rebellion',
#   'Dies Irae',
#   'Code Geass: Hangyaku no Lelouch I - Koudou',
#   'Promare: Lio-hen',
#   'Promare: Galo-hen',
#   'Senkou no Night Raid Specials',
#   'Senkou no Night Raid: Yogen',
#   'First Squad: The Moment of Truth',
#   'Ippatsu Hicchuu!! Devander',
#   'Mazinger Z Movie: Infinity'],
#  'Yuru Yuri♪♪': ['Yuru Yuri,',
#   'Yuru Yuri',
#   'Mini Yuri',
#   'Inugami-san to Nekoyama-san',
#   'Inugami-san to Nekoyama-san: Nekoyama-san to Onsen Ryokou',
#   'Akane-chan',
#   'High Score',
#   'Fudanshi Koukou Seikatsu',
#   'Fudanshi Koukou Seikatsu: Sports no Aki, Bonnou no Aki',
#   'Mikagura Gakuen Kumikyoku (TV)'],
#  'Sword Art Online: Alicization - War of Underworld': ['Sword Art Online Movie: Ordinal Scale',
#   'Sword Art Online: Alicization',
#   'Sword Art Online II',
#   'Sword Art Online: Alicization - War of Underworld Reflection',
#   'Chou Yuu Sekai: Being the Reality',
#   'Sword Art Online: Alicization - War of Underworld 2nd Season',
#   'Hoshi wo Ou Kodomo',
#   'Tenkuu no Escaflowne Recaps',
#   'Sword Art Online: Alicization - Recollection',
#   'Log Horizon'],
#  'Saint☆Oniisan (Movie)': ['Servant x Service',
#   'Bakuon!! no Kobeya',
#   'Oishinbo: Nichibei Kome Sensou',
#   'Non Non Biyori 3rd Season',
#   'Himouto! Umaru-chanS',
#   'Saint☆Oniisan',
#   'Ganbare! Memeko-chan',
#   'Hana no Kakarichou',
#   'Kariage-kun',
#   'Manga Hana no Kakarichou'],
#  'Mobile Suit Gundam 0080: War in the Pocket': ["Mobile Suit Gundam: Char's Counterattack",
#   'Mobile Suit Zeta Gundam: A New Translation III - Love Is the Pulse of the Stars',
#   'Mobile Suit Zeta Gundam: A New Translation - Heir to the Stars',
#   'Mobile Suit Gundam Thunderbolt: December Sky',
#   'Mobile Suit Gundam Thunderbolt',
#   'Mobile Suit Gundam 00',
#   'Mobile Suit Gundam Wing',
#   'Mobile Suit Gundam 0083: Stardust Memory - The Mayfly of Space',
#   "Mobile Suit Gundam: Hathaway's Flash 3",
#   "Mobile Suit Gundam: Hathaway's Flash 2"],
#  'Mahoujin Guruguru (2017)': ['Mahou Gakuen Lunar! Aoi Ryuu no Himitsu',
#   'Zettai Bouei Leviathan: Mini Takibi Gekijou',
#   'Onegai My Melody Sukkiri♪',
#   'Onegai♪My Melody Kirara★',
#   'Zettai Bouei Leviathan',
#   'Onegai My Melody: Kuru Kuru Shuffle!',
#   'Mai-Otome Specials',
#   'Gedo Senki',
#   'Grandeek',
#   'Jue Ji'],
#  'Kara no Kyoukai 2: Satsujin Kousatsu (Zen)': ['Kara no Kyoukai 7: Satsujin Kousatsu (Kou)',
#   'Durarara!!x2 Ten',
#   'Durarara!!x2 Shou',
#   'Durarara!!x2 Ketsu',
#   'Durarara!!',
#   'Durarara!!x2 Shou: Watashi no Kokoro wa Nabe Moyou',
#   'Huangli Shi',
#   'Durarara!!x2 Ketsu: Dufufufu!!',
#   'Durarara!!x2 Ten: Onoroke Chakapoko',
#   'Kara no Kyoukai 5: Mujun Rasen'],
#  'Jungle wa Itsumo Hare nochi Guu': ['Tanaka-kun wa Itsumo Kedaruge',
#   'Azumanga Daioh',
#   'Danshi Koukousei no Nichijou',
#   'Minami-ke',
#   'Mitsudomoe Zouryouchuu!',
#   'Urashimasakatasen no Nichijou',
#   'Rifle Is Beautiful',
#   'X Maiden',
#   'Pan de Peace!',
#   'Sansha Sanyou'],
#  'Jormungand': ['Jormungand: Perfect Order',
#   'Saint Seiya: Saintia Shou',
#   'Early Reins',
#   'Jormungand: Perfect Order Recap',
#   'Kizuoibito',
#   'Meisou-Ou Border',
#   'Michiko to Hatchin',
#   'Shishigari',
#   'Kaitei Daisensou: Ai no 20,000 Miles',
#   'Legend of Lemnear: Kyokuguro no Tsubasa Valkisas Pilot Film'],
#  'Higashi no Eden': ['No.6',
#   'Shin Taketori Monogatari: 1000-nen Joou',
#   'ef: A Tale of Memories.',
#   'Ikebukuro West Gate Park',
#   'ef: A Tale of Memories. - Recollections',
#   'Robotics;Notes',
#   'Tomoe ga Yuku!',
#   'ID:Invaded',
#   'Occultic;Nine',
#   'Loups=Garous #Overture'],
#  'Hello World': ['Mou Hitotsu no Mirai wo.',
#   'Hoshi no Ko Poron',
#   'Amanatsu',
#   'Adachi-ga Hara',
#   'Seikaisuru Kado: Ekwari',
#   'Mirai Arise',
#   '100-man-nen Chikyuu no Tabi: Bander Book',
#   'Daikyouryuu Jidai',
#   'Dimension Loop',
#   'Plus 50000-nen'],
#  'Gochuumon wa Usagi Desu ka??': ['Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??',
#   'Yuru Camp△',
#   'Gochuumon wa Usagi Desu ka??: Sing for You',
#   'Aggressive Retsuko (ONA)',
#   'Jungle wa Itsumo Hare nochi Guu Final',
#   'Sora yori mo Tooi Basho: Yokoku',
#   'Choboraunyopomi Gekijou Dai San Maku Ai Mai Mii: Surgical Friends'],
#  'Giant Robo the Animation: Chikyuu ga Seishi Suru Hi': ['Guilty Crown: Lost Christmas - An Episode of Port Town',
#   'Shin Mazinger Shougeki! Z-hen',
#   'Code Geass: Hangyaku no Lelouch R2',
#   'Code Geass: Fukkatsu no Lelouch',
#   'Code Geass: Hangyaku no Lelouch',
#   'Toaru Kagaku no Railgun S',
#   'Toaru Kagaku no Railgun',
#   'Choujin Locke: Shinsekai Sentai',
#   'Toaru Kagaku no Railgun T',
#   'Choujin Locke: Mirror Ring'],
#  'Douluo Dalu 2nd Season': ['Tenka Hyakken: Meiji-kan e Youkoso!',
#   'Xiyouji zhi Dasheng Guilai',
#   'Wu Geng Ji 2nd Season',
#   'Wu Geng Ji',
#   'Wu Geng Ji 3rd Season',
#   'Xia Lan',
#   'Koihime†Musou',
#   'Tian Guan Ci Fu',
#   'Xing Chen Bian',
#   'Xue Ying Ling Zhu'],
#  'Detective Conan Movie 12: Full Score of Fear': ['Detective Conan Movie 05: Countdown to Heaven',
#   'The Disappearance of Conan Edogawa: The Worst Two Days in History',
#   'Detective Conan Movie 10: Promo Special',
#   'Detective Conan Movie 09: Promo Special',
#   'Detective Conan Magic File 2: Kudou Shinichi - The Case of the Mysterious Wall and the Black Lab',
#   'Detective Conan OVA 11: A Secret Order from London',
#   'Detective Conan Magic File 5: Niigata - Tokyo Omiyage Capriccio',
#   'Detective Conan OVA 07: A Challenge from Agasa! Agasa vs. Conan and the Detective Boys',
#   'Detective Conan Magic File 4: Osaka Okonomiyaki Odyssey',
#   'Detective Conan OVA 06: Follow the Vanished Diamond! Conan & Heiji vs. Kid!'],
#  'Detective Conan Movie 09: Strategy Above the Depths': ['Detective Conan Movie 07: Crossroad in the Ancient Capital',
#   'Detective Conan Movie 01: The Timed Skyscraper',
#   'Detective Conan Movie 02: The Fourteenth Target',
#   'Detective Conan Movie 04: Captured in Her Eyes',
#   'Detective Conan Movie 03: The Last Wizard of the Century',
#   'Detective Conan Movie 08: Magician of the Silver Sky',
#   'Detective Conan: Episode One - The Great Detective Turned Small',
#   'Detective Conan (TV)',
#   'Detective Conan: Black History',
#   'Detective Conan: Black History 2'],
#  'City Hunter 3': ['Lupin III vs. Detective Conan: The Movie',
#   'City Hunter',
#   'City Hunter 2',
#   "City Hunter '91",
#   'City Hunter: Hyakuman Dollar no Inbou',
#   'City Hunter: The Secret Service',
#   'City Hunter: Ai to Shukumei no Magnum',
#   'City Hunter: Bay City Wars',
#   'Muhyo to Rouji no Mahouritsu Soudan Jimusho 2nd Season',
#   'Muhyo to Rouji no Mahouritsu Soudan Jimusho'],
#  'Break Blade 4: Sanka no Chi': ['Break Blade 3: Kyoujin no Kizu',
#   'Break Blade 2: Ketsubetsu no Michi',
#   'Break Blade 1: Kakusei no Toki',
#   'Wakusei Daikaiju Negadon',
#   'Kikou Sennyo Rouran',
#   'Huan Jing Nuo De Lin',
#   'God Mazinger',
#   'Ark',
#   'Getter Robo Go',
#   'Neppuu Kairiku Bushi Road'],
#  'Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e (TV)': ['Harmonie',
#   'Kotonoha no Niwa',
#   'Beastars',
#   'Beastars 2nd Season',
#   'Yuuki Yuuna wa Yuusha de Aru',
#   'Kanojo to Kanojo no Neko: Everything Flows',
#   'Koukai Benjo The Animation',
#   'Gakkougurashi!',
#   'Byulbyul Iyagi',
#   'Byulbyul Iyagi 2'],
#  'Wotaku ni Koi wa Muzukashii: Youth': ['Anisava',
#   'Ojisan to Marshmallow',
#   'Ohayou! Spank (Movie)',
#   'Ore no Imouto ga Konnani Kawaii Wake ga Nai. Specials',
#   'Love Hina Christmas Special: Silent Eve',
#   'Toradora!',
#   'Yugami-kun ni wa Tomodachi ga Inai',
#   'Acchi Kocchi (TV): Place=Princess',
#   'Toradora! Recap',
#   'Acchi Kocchi (TV)'],
#  'The Everlasting Guilty Crown': ["Kyoukai no Kanata Movie: I'll Be Here - Kako-hen - Yakusoku no Kizuna",
#   'IDOLiSH7',
#   'IDOLiSH7 Vibrato',
#   'Kawaki wo Ameku',
#   'Yamiyo',
#   'BanG Dream! 2nd Season',
#   'Snow Halation',
#   'Uchiage Hanabi',
#   'Sleeping Beauty',
#   'Koi to Byounetsu'],
#  'Tasogare Otome x Amnesia': ['Tasogare Otome x Amnesia: Taima Otome',
#   'Yamada-kun to 7-nin no Majo (TV)',
#   'Kyoukai no Rinne 3rd Season',
#   'Kyoukai no Rinne 2nd Season',
#   'Jigoku Sensei Nube',
#   'Miyuki',
#   'Kannagi: Moshimo Kannagi ga Attara...',
#   'Honto ni Atta! Reibai Sensei',
#   'Saiki Kusuo no Ψ-nan (ONA)',
#   'Yamada-kun to 7-nin no Majo'],
#  'Saint Seiya': ['Avenger',
#   'Star Ocean EX',
#   'Saint Seiya: Shinku no Shounen Densetsu',
#   'Saint Seiya: Soul of Gold',
#   'Dragon Ball Z Movie 04: Super Saiyajin da Son Gokuu',
#   'Final Fantasy: Unlimited',
#   'Landlock',
#   'Mujigen Hunter Fandora',
#   'Fractale',
#   "Toruru's Adventure"],
#  'Overlord II': ['Mahou Sensei Negima! Movie: Anime Final',
#   'Nanatsu no Taizai OVA',
#   'Nanatsu no Taizai: Kamigami no Gekirin',
#   'Nanatsu no Taizai: Eiyuu-tachi wa Hashagu',
#   'Log Horizon',
#   'Overlord Movie 2: Shikkoku no Eiyuu',
#   'Overlord Movie 1: Fushisha no Ou',
#   'Bai Niao Gu',
#   'Cardfight!! Vanguard: Asia Circuit-hen',
#   'Shenmue: The Movie'],
#  'Neko no Ongaeshi': ['Kino no Tabi: The Beautiful World - Nanika wo Suru Tame ni - Life Goes On.',
#   'Kino no Tabi: The Beautiful World - Byouki no Kuni - For You',
#   'Chirin no Suzu',
#   'Eien no Filena',
#   'Kaze wo Mita Shounen',
#   'Hamelin no Violin Hiki',
#   'Eien no Aselia',
#   'Katasumi no Uroko',
#   'Mirai no Mirai',
#   'Saiyuuki Gaiden: Kouga no Shou'],
#  'Musekinin Kanchou Tylor': ['Musekinin Galaxy☆Tylor',
#   'Ten Little Gall Force',
#   'Space☆Dandy',
#   'Seihou Tenshi Angel Links: Meifon no Special Kaisetsu Corner',
#   'Ryuuseiki Gakusaver',
#   'Uchuu Senkan Yamato Pilot Film',
#   'Crayon Shin-chan Gaiden: Alien vs. Shinnosuke',
#   'Ginga Eiyuu Densetsu: Waga Yuku wa Hoshi no Taikai',
#   'Ginga Eiyuu Densetsu Gaiden',
#   'Big Wars: Kami Utsu Akaki Kouya ni'],
#  'Love Live! School Idol Project 2nd Season': ['Love Live! The School Idol Movie',
#   'Love Live! Sunshine!! 2nd Season',
#   'Starmyu',
#   'Love Live! Sunshine!! The School Idol Movie: Over the Rainbow',
#   'Tenshi no 3P!',
#   'Omoide no Album',
#   'K-On!: Live House!',
#   'K-On!!',
#   'K-On!!: Keikaku!',
#   'I★Chu: Étoile Stage'],
#  'Little Witch Academia': ['Little Witch Academia: Mahoujikake no Parade',
#   'Happy Seven: The TV Manga',
#   'Otogi Juushi Akazukin OVA',
#   'Mahou Yuugi 2D',
#   'Märchen Mädchen Specials',
#   'Mahoutsukai Nara Miso wo Kue!',
#   'Mahoujin Guruguru',
#   'Slayers: The Motion Picture',
#   'Dokidoki♡Densetsu: Mahoujin Guruguru',
#   'Fullmetal Alchemist: The Sacred Star of Milos Specials'],
#  'Kuroshitsuji': ['Kuroshitsuji: Book of Murder',
#   'Kuroshitsuji: Book of Circus',
#   'Kuroshitsuji Movie: Book of the Atlantic',
#   'Kuroshitsuji Recap',
#   'Kuroshitsuji: Sono Shitsuji, Kougyou',
#   'Kuroshitsuji II',
#   'Tactics',
#   'Da Li Si Ri Zhi',
#   'Makai Ouji: Devils and Realist',
#   'Kimetsu no Yaiba Movie: Mugen Ressha-hen'],
#  'InuYasha (TV)': ['InuYasha: Kanketsu-hen',
#   'InuYasha Movie 3: Tenka Hadou no Ken',
#   'InuYasha Movie 2: Kagami no Naka no Mugenjo',
#   'InuYasha Movie 1: Toki wo Koeru Omoi',
#   'InuYasha Movie 4: Guren no Houraijima',
#   'Fate/stay night TV Reproduction',
#   'Fate/Prototype',
#   'Inyouchuu Etsu',
#   'Kuroshitsuji: Sono Shitsuji, Kougyou',
#   'Fate/stay night'],
#  'Danshi Koukousei no Nichijou Specials': ['Gin no Saji',
#   'Gin no Saji 2nd Season',
#   'Seitokai Yakuindomo OVA',
#   'Seitokai Yakuindomo Movie 2',
#   'Seitokai Yakuindomo',
#   'Hitoribocchi no Marumaru Seikatsu',
#   'Aiura',
#   'Senryuu Shoujo',
#   'Gu-Gu Ganmo',
#   'Amanchu! Advance'],
#  'Colorful (Movie)': ['Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai. Movie',
#   'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#   'Kanon (2006)',
#   'Air',
#   'Kataribe Shoujo Honoka',
#   'Kyoukai no Kanata: Mini Gekijou',
#   'Mokke Specials',
#   'Kyoukai no Kanata',
#   'Flying Witch Petit Special',
#   'Wakaokami wa Shougakusei! Movie'],
#  'Bishoujo Senshi Sailor Moon S': ['Bishoujo Senshi Sailor Moon R: The Movie',
#   'Bishoujo Senshi Sailor Moon SuperS',
#   'Bishoujo Senshi Sailor Moon SuperS Specials',
#   'Mahou no Stage Fancy Lala',
#   'Kaitou Saint Tail',
#   'Irozuku Sekai no Ashita kara',
#   'Lady Jewelpet',
#   'Mahou no Mako-chan',
#   'D.C.: Da Capo',
#   'Bishoujo Senshi Sailor Moon SuperS Gaiden: Ami-chan no Hatsukoi'],
#  'Baby Steps': ['Mix',
#   'Haikyuu!!: Tokushuu! Haru-kou Volley ni Kaketa Seishun',
#   'Whistle!',
#   'Ballroom e Youkoso',
#   'Cross Game',
#   'Miyuki',
#   'Aoki Densetsu Shoot!',
#   'Diamond no Ace',
#   'Kuroko no Basket',
#   'Kuroko no Basket NG-shuu'],
#  'Yuusha-Ou GaoGaiGar': ['Bubblegum Crisis Tokyo 2040',
#   'SF Saiyuuki Starzinger (Movie)',
#   'Dennou Boukenki Webdiver',
#   "B'T X",
#   'Tetsujin 28-gou: Tanjou-hen',
#   'Sakura Taisen',
#   'Oban Star-Racers',
#   'Hyakujuu-Ou GoLion',
#   'Sakura Taisen: Gouka Kenran',
#   'Daikuu Maryuu Gaiking'],
#  'Vampire Hunter D (2000)': ['Kyoufu Densetsu Kaiki! Frankenstein',
#   'Biohazard: Damnation',
#   'Tenshi ni Narumon!',
#   'Hametsu no Mars',
#   'Ayakashi',
#   'Fortune Arterial: Akai Yakusoku - Tadoritsuita Basho',
#   'Vampire Hunter D',
#   'Deadman Wonderland: Akai Knife Tsukai',
# ...
#   'Ken En Ken: Aoki Kagayaki',
#   'Xing Chen Bian',
#   'Xue Ying Ling Zhu',
#   'Da Zhu Zai'],
#  'Doupo Cangqiong 3rd Season': ['Cike Wu Liuqi Fanwai',
#   'Re:␣Hamatora',
#   'Hamatora The Animation',
#   'Tiger & Bunny',
#   'Tiger & Bunny Movie 2: The Rising',
#   'Tantei Opera Milky Holmes: Psycho no Aisatsu',
#   'Hamatora The Animation: Saishuukai Chokuzen! Mao ga Okuru',
#   'Tantei Opera Milky Holmes: Fun Fun Party Night♪ - Ken to Janet no Okurimono',
#   'Fw:Hamatora',
#   'Taboo Tattoo'],
#  'Cike Wu Liuqi': ['Break Blade 3: Kyoujin no Kizu',
#   'Break Blade 2: Ketsubetsu no Michi',
#   'Break Blade 1: Kakusei no Toki',
#   'Wakusei Daikaiju Negadon',
#   'Kikou Sennyo Rouran',
#   'Huan Jing Nuo De Lin',
#   'God Mazinger',
#   'Ark',
#   'Getter Robo Go',
#   'Neppuu Kairiku Bushi Road'],
#  'Break Blade 2: Ketsubetsu no Michi': ['Hashire Melos (1981)',
#   'Ochou Fujin no Gensou',
#   'Oshin',
#   'Animation de Tsutaeru: Hibakusha kara no Tegami',
#   'Ecchan no Sensou',
#   'Zeno: Kagirinaki Ai ni',
#   'Hibakusha kara no Tegami',
#   'Happyakuyachou Hyouri Kewaishi',
#   'Jangdokdae',
#   'Isewan Taifuu Monogatari'],
#  'Ushiro no Shoumen Daare': ['Hakumei to Mikochi: Neji to Bed to Irori to Bakuchi',
#   'Konohana Kitan',
#   'Honzuki no Gekokujou: Shisho ni Naru Tame ni wa Shudan wo Erandeiraremasen',
#   'Honzuki no Gekokujou: Shisho ni Naru Tame ni wa Shudan wo Erandeiraremasen 2nd Season',
#   'Happy Forest',
#   'Shin Maple Town Monogatari: Palm Town-hen',
#   'Maple Town Monogatari',
#   'Green Co-Op CMs',
#   'Maple Town Monogatari (Movie)',
#   'Shin Maple Town Monogatari: Palm Town-hen - Konnichiwa! Atarashii Machi'],
#  'Udon no Kuni no Kiniro Kemari': ['Herlock Saga: Nibelung no Yubiwa',
#   'Uchuu Kaizoku Captain Herlock: Arcadia-gou no Nazo',
#   'Odin: Koushi Hansen Starlight',
#   'MAPS: Densetsu no Samayoeru Seijin-tachi',
#   'Ginga Tetsudou 999',
#   'Ginga Tetsudou 999 (ONA)',
#   'Sayonara Ginga Tetsudou 999: Andromeda Shuuchakueki',
#   'Ginga Tetsudou 999 (Movie)',
#   'Queen Emeraldas',
#   'Venus Senki'],
#  'Uchuu Kaizoku Captain Herlock': ['Toaru Kagaku no Railgun',
#   'Choujin Locke: Shinsekai Sentai',
#   'Toaru Kagaku no Railgun T',
#   'Choujin Locke: Mirror Ring',
#   'Armed Blue Gunvolt',
#   'Choujin Locke Special',
#   'Nobunagun',
#   'Toaru Kagaku no Railgun: Misaka-san wa Ima Chuumoku no Mato Desu kara',
#   'Persona: Trinity Soul',
#   'Infini-T Force'],
#  'Toaru Kagaku no Railgun': ['Tetsuwan Birdy Decode',
#   'Inazma Delivery',
#   'Inazma Delivery: Dougyousha Attack-hen',
#   'Choujigen Game Neptune The Animation: Yakusoku no Eien - True End',
#   'G-On Riders',
#   'Summer Wars',
#   'Gijinka de Manabo!',
#   'Fireball Humorous',
#   'Koukaku no Pandora: Pandoradio',
#   'Galaxy Angel Music Collection: Shouen to Shien no Cassoulet'],
#  'Tetsuwan Birdy Decode:02': ['Seitokai Yakuindomo* OVA',
#   'Nichijou',
#   'Seitokai Yakuindomo*',
#   'Yatogame-chan Kansatsu Nikki 2nd Season',
#   'Isshuukan Friends.',
#   'Amanchu!: Yakusoku no Natsu to Atarashii Omoide no Koto',
#   'Nichijou: Nichijou no 0-wa',
#   'Yatogame-chan Kansatsu Nikki',
#   'Amanchu!',
#   'Jungle wa Itsumo Hare nochi Guu'],
#  'Seitokai Yakuindomo*': ['Nurarihyon no Mago OVA',
#   'Nurarihyon no Mago',
#   'Nurarihyon no Mago: Sennen Makyou Recaps',
#   'Gegege no Kitarou: Tamashii to Art',
#   'Dokkaebi Bangmang-I',
#   'Nurarihyon no Mago: Gekitou Dai Futsal Taikai! Nuragumi W Cup!!',
#   'Ushio to Tora (TV)',
#   'Toukiden: The Age of Demons - Introduction',
#   'Toukiden 2',
#   'Tokyo Ravens: Kon ga Oshiete Moshi Agemasu! Maru Wakari Tokyo Ravens'],
#  'Nurarihyon no Mago OVA': ['Jewelpet Magical Change',
#   'Futari wa Precure: Max Heart',
#   'Fresh Precure! Movie: Omocha no Kuni wa Himitsu ga Ippai!?',
#   'Futari wa Precure: Splash☆Star Maji★Doki♥ Theater',
#   'Futari wa Precure: Splash☆Star',
#   'Mahou no LumiTear',
#   'Jewelpet Movie: Sweets Dance Princess',
#   'Precure kara Minna e no Ouen Movie',
#   'Mahou no Tenshi Creamy Mami no Otogibanashi',
#   'Precure All Stars Movie New Stage: Mirai no Tomodachi'],
#  'Ojamajo Doremi Na-i-sho': ['Fushigi na Somera-chan',
#   'Hitotsubu ni Kawaranu Ai wo Komete',
#   'Shiawase Pasta Story',
#   'Zetsumetsu Kigu Shoujo: Amazing Twins',
#   'Agukaru: Play with Ibaraki-hen Episode 0',
#   'Endro~!',
#   'Kamisama Minarai: Himitsu no Cocotama',
#   'Kirakira Happy★Hirake! Cocotama',
#   'Binzume Yousei',
#   'Kirakira☆Precure A La Mode Movie: Paritto! Omoide no Mille-Feuille!'],
#  'Machikado Mazoku': ["Kyoukai no Kanata Movie 1: I'll Be Here - Kako-hen",
#   "Persona 3 the Movie 2: Midsummer Knight's Dream",
#   'The Epic Of ZektBach',
#   'Persona 3 the Movie 1: Spring of Birth',
#   'Hen Xi You',
#   'Shakugan no Shana Movie',
#   'Persona 5 the Animation Recap',
#   'Persona 5 the Animation: The Day Breakers',
#   'Witch Craft Works: Takamiya-kun to Imouto no Warudakumi',
#   'Kaze no Matasaburou (Movie)'],
#  "Kyoukai no Kanata Movie 1: I'll Be Here - Kako-hen": ['Kyou kara Maou!',
#   'Kyou kara Maou! R',
#   'Hong Haier: Juezhan Huoyanshan',
#   'Majutsushi Orphen',
#   'Beelzebub-jou no Okinimesu mama.',
#   'InuYasha: Kuroi Tessaiga',
#   'Dragon Ball Z Movie 10: Kiken na Futari! Super Senshi wa Nemurenai',
#   'Akuma Tou no Prince: Mitsume ga Tooru',
#   'Makai Senki Disgaea',
#   'Hoozuki no Reitetsu 2nd Season: Sono Ni'],
#  'Kyou kara Maou!': ['Kuroko no Basket Movie 3: Winter Cup - Tobira no Mukou',
#   'Teekyuu 8 Specials',
#   'Teekyuu 6 Specials',
#   'Tennis no Ouji-sama: Atobe kara no Okurimono - Kimi ni Sasageru Tennis Prince Matsuri',
#   'Usakame Special',
#   'Teekyuu 8',
#   'Shounen Sunday CM: All-Star Total Appearance',
#   'Teekyuu 7 Specials',
#   'Shiritsu Araiso Koutougakkou Seitokai Shikkoubu',
#   'Tennis no Ouji-sama: Zenkoku Taikai-hen'],
#  'Kuroko no Basket Movie 3: Winter Cup - Tobira no Mukou': ['Mizu no Kotoba',
#   'RahXephon Kansoukyoku: Kanojo to Kanojo Jishin to - Thatness and Thereness',
#   'Casshern Sins',
#   'Btooom!',
#   'Blame! Movie',
#   'Kokoroya',
#   'Dimension W: W no Tobira Online - Rose no wo Nayami Soudanshitsu',
#   'Ouritsu Uchuugun: Honneamise no Tsubasa Pilot',
#   'Asylum Session',
#   'Dimension W: Robot wa Sentou no Yume wo Miruka'],
#  'Inuyashiki': ['Hitohira',
#   'Asako Get You!!',
#   'Nagato Yuki-chan no Shoushitsu',
#   'Chitose Get You!!',
#   'Chuusotsu Worker kara Hajimeru Koukou Seikatsu',
#   'Kuzu no Honkai',
#   'Non Non Biyori',
#   'Non Non Biyori Repeat',
#   'Non Non Biyori Repeat: Hotaru ga Tanoshinda',
#   'A-Channel+smile'],
#  'Hourou Musuko': ['Hakuouki Movie 1: Kyoto Ranbu',
#   'Hakuouki Reimeiroku',
#   'Hakuouki',
#   'Hakuouki OVA',
#   'Hakuouki Hekketsuroku Episode 0',
#   'Kamishibai Itazura Tanuki no Maki',
#   'Fate/Apocrypha Recaps',
#   'Sirius',
#   'Honoo no Mirage',
#   'Honoo no Mirage: Muyou no Michi'],
#  'Hakuouki Movie 1: Kyoto Ranbu': ['Golden Kamuy',
#   'Golden Kamuy 2nd Season OVA',
#   'Golden Kamuy OVA',
#   'Hashire Melos (Movie)',
#   'Yokoyama Mitsuteru Sangokushi',
#   'Souten Kouro',
#   'Onihei Pilot',
#   'Onihei: Sono Otoko, Heizou Hasegawa',
#   'Onihei',
#   'Karasu Tengu Kabuto'],
#  'Golden Kamuy': ['Detective Conan OVA 09: The Stranger in 10 Years...',
#   'Detective Conan Movie 15: Quarter of Silence',
#   'Detective Conan Movie 10: Requiem of the Detectives',
#   'Detective Conan Movie 17: Private Eye in the Distant Sea',
#   'Detective Conan vs. Wooo',
#   'Detective Conan Movie 11: Jolly Roger in the Deep Azure',
#   'Detective Conan: Conan vs. Kid - Jet Black Sniper',
#   'Detective Conan Movie 16: The Eleventh Striker',
#   'Detective Conan Bonus File: Fantasista Flower',
#   'Detective Conan Movie 06: The Phantom of Baker Street'],
#  'Detective Conan Movie 17: Private Eye in the Distant Sea': ['Bokura wa Minna Kawai-sou: Hajimete no',
#   'Sora no Manimani',
#   'Toradora!',
#   'Yugami-kun ni wa Tomodachi ga Inai',
#   'Acchi Kocchi (TV): Place=Princess',
#   'Toradora! Recap',
#   'Acchi Kocchi (TV)',
#   'The Kabocha Wine',
#   'Amagami SS+ Plus',
#   'Boku wa Tomodachi ga Sukunai Episode 0'],
#  'Bokura wa Minna Kawai-sou': ['Hataraku Saibou Specials',
#   'Shingeki no Kyojin Season 3 Specials',
#   'Owari no Seraph: Nagoya Kessen-hen - Owaranai Seraph - Nagoya Kessen-hen',
#   'Tobidase! Machine Hiryuu',
#   'Hayate no Gotoku! Heaven Is a Place on Earth',
#   'Kuroshitsuji II Specials',
#   'Look Plus One Piece Special Movie',
#   'Sumeba Miyako no Cosmos-sou Suttoko Taisen Dokkoida',
#   'Tokyo Ravens: Kon ga Oshiete Moshi Agemasu! Maru Wakari Tokyo Ravens',
#   'Osomatsu-san'],
#  'Binbougami ga!': ['Digimon Savers',
#   'Digimon Tamers',
#   'Digimon Frontier: Ornismon Fukkatsu!!',
#   'Pokemon Movie 14 Black: Victini to Shiroki Eiyuu Reshiram',
#   'Pokemon Movie 14 White: Victini to Kuroki Eiyuu Zekrom',
#   'Pokemon Movie 05: Mizu no Miyako no Mamorigami Latias to Latios',
#   'One Piece Film: Gold',
#   'One Piece Film: Strong World',
#   'One Piece Film: Z',
#   'One Piece: Heart of Gold'],
#  'Arashi no Yoru ni': ['Choukadou Girl ⅙',
#   'Arakawa Under the Bridge',
#   'Ueno-san wa Bukiyou',
#   'One Pound Gospel',
#   'Danna ga Nani wo Itteiru ka Wakaranai Ken',
#   'Mikakunin de Shinkoukei: Kamoniku tte Midori-ppoi Aji ga Suru no ne.',
#   'Cinderella Express',
#   "Working'!!",
#   'Working!!!',
#   'Working!!!: Lord of the Takanashi'],
#  'Arakawa Under the Bridge x Bridge': ['Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??',
#   'Yuru Camp△',
#   'Gochuumon wa Usagi Desu ka??: Sing for You',
#   'Aggressive Retsuko (ONA)',
#   'Jungle wa Itsumo Hare nochi Guu Final',
#   'Sora yori mo Tooi Basho: Yokoku',
#   'Choboraunyopomi Gekijou Dai San Maku Ai Mai Mii: Surgical Friends'],
#  'Aggressive Retsuko (ONA)': ['Free!',
#   'Slam Dunk: Zenkoku Seiha Da! - Sakuragi Hanamichi',
#   'Haikyuu!! Second Season',
#   'Haikyuu!!: Karasuno Koukou vs. Shiratorizawa Gakuen Koukou',
#   'Haikyuu!! Movie 2: Shousha to Haisha',
#   'Haikyuu!! Movie 1: Owari to Hajimari',
#   'Slam Dunk',
#   'Haikyuu!!',
#   'Haikyuu!!: To the Top',
#   'Haikyuu!!: Riku vs. Kuu'],
#  'Free!: Eternal Summer': ['Stitch! Perfect Memory',
#   'Stitch to Suna no Wakusei',
#   'Komachi to Dangorou',
#   'Urusei Yatsura OVA',
#   'Soreyuke! Uchuu Senkan Yamamoto Yohko',
#   'Pokemon Movie 07: Rekkuu no Houmonsha Deoxys',
#   'Digimon Universe: Appli Monsters',
#   'Doraemon: Time Machine de Oshougatsu',
#   'Sonic X',
#   'Birth'],
#  'Digimon Adventure: Bokura no War Game!': ['Switch',
#   'Detective Conan Movie 20: The Darkest Nightmare',
#   'Detective Conan Movie 14: The Lost Ship in the Sky',
#   'Detective Conan Movie 18: The Sniper from Another Dimension',
#   'Detective Conan Movie 19: The Hellfire Sunflowers',
#   'Hero Mask',
#   'ACCA: 13-ku Kansatsu-ka - Regards',
#   'Columbos',
#   'Detective Conan Movie 21: The Crimson Love Letter',
#   'B: The Beginning'],
#  'Detective Conan Movie 22: Zero The Enforcer': ['Bishoujo Senshi Sailor Moon',
#   'Bishoujo Senshi Sailor Moon R',
#   'Bishoujo Senshi Sailor Moon Crystal',
#   'Bishoujo Senshi Sailor Moon Memorial',
#   'Bishoujo Senshi Sailor Moon Eternal',
#   'Bishoujo Senshi Sailor Moon SuperS Specials',
#   'Kaitou Saint Tail',
#   'Lady Jewelpet',
#   'Mahou no Mako-chan',
#   'Bishoujo Senshi Sailor Moon SuperS Gaiden: Ami-chan no Hatsukoi'],
#  'Bishoujo Senshi Sailor Moon Crystal Season III': ["Ningen Shikkaku: Director's Cut-ban",
#   'Inaka Isha',
#   'Narutaru: Mukuro Naru Hoshi Tama Taru Ko',
#   'Rainbow: Nisha Rokubou no Shichinin',
#   'One Outs',
#   'Monster',
#   'Kataribe Jinkou Chinou ga Tsubuyaku Noroi no Yogen',
#   'Human Lost: Ningen Shikkaku',
#   'Phantom: Requiem for the Phantom',
#   'Usogui'],
#  'Aoi Bungaku Series': ['Ajin Part 1: Shoudou',
#   'Ajin Part 3: Shougeki',
#   'Ajin Part 2: Shoutotsu',
#   'Mouryou no Hako: Chuuzenji Atsuko no Jikenbo - Hako no Yurei no Koto',
#   'Monster Extra: Hottan',
#   'Kara no Kyoukai: Mirai Fukuin',
#   'Kara no Kyoukai: Mirai Fukuin - Extra Chorus',
#   'Kaijuu no Kodomo',
#   "Le Chevalier D'Eon",
#   'High School Mystery: Gakuen Nanafushigi'],
#  'Ajin 2nd Season': ['Urusei Yatsura Movie 1: Only You',
#   'Onegai☆Teacher: Marie, Ai no Gekijou',
#   'Seraphim Call',
#   'Seihou Tenshi Angel Links',
#   'Hiatari Ryoukou! Yume no Naka ni Kimi ga Ita',
#   'Love Hina Haru Special: Kimi Sakura Chiru Nakare!!',
#   'Hotori: Tada Saiwai wo Koinegau',
#   'Taiyou no Mokushiroku: A Spirit of the Sun',
#   'Ginga Tetsudou 999: Hoshizora wa Time Machine',
#   'Pale Cocoon'],
#  'Urusei Yatsura Movie 2: Beautiful Dreamer': ['Soukou Kihei Votoms',
#   'Uchuu no Kishi Tekkaman Blade II',
#   'Taiyou no Kiba Dagram',
#   "Dennou Sentai Voogie's★Angel",
#   'Mobile Suit Gundam SEED Special Edition',
#   'Soliton no Akuma',
#   'Zone of the Enders: 2167 Idolo',
#   'Mobile Suit Gundam SEED Destiny Special Edition',
#   'Mobile Suit Gundam ZZ',
#   'Aoki Ryuusei SPT Layzner OVA'],
#  'Soukou Kihei Votoms': ['Appleseed XIII',
#   'Cop Craft',
#   'Cyber City Oedo 808',
#   'Hero Mask',
#   'Kidou Keisatsu Patlabor 2 the Movie',
#   'Dirty Pair',
#   'Dirty Pair OVA',
#   'Dirty Pair: Lovely Angels yori Ai wo Komete',
#   'Burn Up Excess',
#   'Kidou Keisatsu Patlabor: On Television'],
#  'Psycho-Pass Movie': ['Mobile Suit Gundam SEED',
#   'Mobile Suit Gundam SEED Destiny',
#   'Gunparade Orchestra',
#   'Seikai no Danshou: Tanjou',
#   'Macross Plus Movie Edition',
#   'Gunparade March: Arata Naru Kougunka',
#   'Blue Gender: The Warrior',
#   'Seikai no Senki II',
#   'Seikai no Senki',
#   'Seikai no Senki III'],
#  'Macross Plus': ['Blood Lad: Kanketsu Kinen',
#   'TO-Y',
#   'Kakushin',
#   'Bronze: Kouji Nanjo Cathexis',
#   'Magical☆Star Kanon 100%',
#   'Pyuu to Fuku! Jaguar: Return of Yaku Ichinenburi',
#   'Pyuu to Fuku! Jaguar',
#   'Kami nomi zo Shiru Sekai: 4-nin to Idol',
#   'Beck',
#   'The Everlasting Guilty Crown'],
#  'Shigatsu wa Kimi no Uso: Moments': ['B: The Beginning',
#   'B: The Beginning 2',
#   'Death Note',
#   'Higurashi no Naku Koro ni Kai',
#   'Bloody Night',
#   'Mouryou no Hako',
#   'Mousou Dairinin',
#   'Top Secret: The Revelation',
#   'Shigofumi',
#   'Higurashi no Naku Koro ni Rei'],
#  'Death Note: Rewrite': ['Mobile Suit Gundam I',
#   'Uchuu Senkan Yamato 2',
#   'Uchuu Senkan Yamato: Kanketsu-hen',
#   'Yamato yo Towa ni',
#   'Uchuu Senkan Yamato III',
#   'After War Gundam X',
#   'Young Herlock wo Oe! Cosmo Warrior Zero Gaiden',
#   'Uchuu Senshi Baldios',
#   'Turn A Gundam',
#   'Ginga Tetsudou 999'],
#  'Mobile Suit Gundam III: Encounters in Space': ['Kyoukai no Kanata: Shinonome',
#   'Musaigen no Phantom World',
#   'Ookami Kodomo no Ame to Yuki',
#   'Puka Puka Juju',
#   'Futari no Oujisama',
#   'Kataribe Shoujo Honoka',
#   'Kyoukai no Kanata: Mini Gekijou',
#   'Mokke Specials',
#   'Kyoukai no Kanata',
#   'Chicchana Yukitsukai Sugar'],
#  'Kyoukai no Kanata: Shinonome': ['Active Raid: Kidou Kyoushuushitsu Dai Hachi Gakari',
#   'Kidou Keisatsu Patlabor',
#   'Tomica Hyper Rescue Drive Head: Kidou Kyuukyuu Keisatsu (TV)',
#   'Virus: Virus Buster Serge',
#   'HeatGuy J',
#   'HeatGuy J Special',
#   'Tenchi Muyou! GXP',
#   'Cop Craft',
#   'Psycho-Pass Movie',
#   'Kidou Keisatsu Patlabor 2 the Movie'],
#  'Kidou Keisatsu Patlabor: On Television': ['Doukyonin wa Hiza, Tokidoki, Atama no Ue.',
#   'Emiya-san Chi no Kyou no Gohan',
#   'Aggressive Retsuko (ONA) 2nd Season',
#   'Gochuumon wa Usagi Desu ka??',
#   'Yuru Camp△',
#   'Gochuumon wa Usagi Desu ka??: Sing for You',
#   'Aggressive Retsuko (ONA)',
#   'Jungle wa Itsumo Hare nochi Guu Final',
#   'Sora yori mo Tooi Basho: Yokoku',
#   'Choboraunyopomi Gekijou Dai San Maku Ai Mai Mii: Surgical Friends'],
#  'Jungle wa Itsumo Hare nochi Guu Final': ['K: Return of Kings',
#   'K: Seven Stories Movie 5 - Memory of Red - Burn',
#   'K: Seven Stories Movie 6 - Circle Vision - Nameless Song',
#   'K',
#   'Hitori no Shita: The Outcast',
#   'K: Seven Stories Movie 4 - Lost Small World - Ori no Mukou ni',
#   'Hitori no Shita: The Outcast 2nd Season',
#   'Hitori no Shita: The Outcast Recap',
#   'K: Seven Stories Movie 2 - Side:Blue - Tenrou no Gotoku',
#   'K: Seven Stories Movie 3 - Side:Green - Uwagaki Sekai'],
#  'K: Return of Kings': ['Initial D Second Stage',
#   'Initial D Fourth Stage',
#   'Initial D Battle Stage 2',
#   'Initial D: Project D to the Next Stage - Project D e Mukete',
#   'Initial D Extra Stage 2',
#   'Initial D Extra Stage',
#   'Initial D Third Stage',
#   'Arrow Emblem Grand Prix no Taka',
#   'Giant Killing',
#   'Ookiku Furikabutte: Kihon no Kihon'],
#  ...}

# %%
pickle.dump(content_based_rec, open('models/content_based_rec.pkl', 'wb') )

# %%
content_based_rec['Death Note']
# Out:
# ['Death Note: Rewrite',
#  'B: The Beginning',
#  'B: The Beginning 2',
#  'Imawa no Kuni no Alice (OVA)',
#  'Mo Ri Shu Guang',
#  'Higurashi no Naku Koro ni Kai',
#  'Bloody Night',
#  'Mouryou no Hako',
#  'Mousou Dairinin',
#  'Top Secret: The Revelation']

# %%
content_recommended_anime_title =[]
content_img_url=[]
for index in range(len(content_based_rec[user_input_text])):
    if index <6:
        anime_title = content_based_rec[user_input_text][index]
        content_recommended_anime_title.append(anime_title)
        img_url = (df_anime[df_anime['title']==anime_title]['img_url'].values[0])
        content_img_url.append(img_url)
print(content_recommended_anime_title)
print(content_img_url)
# Out:
# ['Death Note: Rewrite', 'B: The Beginning', 'B: The Beginning 2', 'Imawa no Kuni no Alice (OVA)', 'Mo Ri Shu Guang', 'Higurashi no Naku Koro ni Kai']
# ['https://cdn.myanimelist.net/images/anime/13/8518.jpg', 'https://cdn.myanimelist.net/images/anime/1564/90469.jpg', 'https://cdn.myanimelist.net/images/anime/1594/93194.jpg', 'https://cdn.myanimelist.net/images/anime/1004/96669.jpg', 'https://cdn.myanimelist.net/images/anime/1939/90507.jpg', 'https://cdn.myanimelist.net/images/anime/12/14114.jpg']
